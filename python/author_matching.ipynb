# %% [markdown]
# # Testing the Models
#
# This notebook contains the steps for testing how well the Greek-Latin Identification and Author Reconciliation models perform on data from HathiTrust.

# %% [markdown]
# ## Load the Necessary Modules
#
# This notebook uses the following modules:
#
# - `csv`: for processing the output of the model
# - `codecarbon`: to track energy usage
# - `pandas`: for opening and working with the CSV files
# - `time`: for timing operations
# - `torch`: for machine learning operations
# - `transformers`: for loading the models and using them
# - `utilities`: for some local helper functions. Note: this is a local file, not a library available through repos like condaforge or pypl.

# %%
import csv
from codecarbon import EmissionsTracker
import pandas as pd
import time
import torch
import torch.nn.functional as F
from transformers.models.auto.tokenization_auto import AutoTokenizer
from transformers.models.auto.modeling_auto import AutoModelForSequenceClassification
from transformers.models.distilbert import DistilBertForSequenceClassification, DistilBertTokenizerFast
import utilities as utilities

# %% [markdown]
# ## Select the Device for Processing
#
# The following block chooses "CUDA" if an NVIDIA GPU is available; "MPS" if an Apple Silicon GPU is available; or "CPU" in the absence of a GPU.

# %%
# General device selection for Colab (CUDA), Mac (MPS), or CPU fallback
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using device: CUDA (GPU)")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using device: MPS (Apple Silicon GPU)")
else:
    device = torch.device("cpu")
    print("Using device: CPU")
# Out:
# Using device: MPS (Apple Silicon GPU)

# %% [markdown]
# ## Load the DLL Catalog Data
#
# The authority and work records from the DLL Catalog are loaded from CSV files and converted into Python dictionaries. These will be used as lookup tables to translate the outputs from the Author Reconciliation model into more comprehensible information for humans (e.g., "Julius Caesar", not "A4644").

# %%
# Read in the authors data
authors = pd.read_csv('../data/authors_db.csv',encoding='utf-8',quotechar='"')
# Read in the works data
works = pd.read_csv('../data/works_db.csv',encoding='utf-8',quotechar='"')

# Change the names of the columns to be lower case without spaces or punctuation
authors = authors.rename(columns={'Variant':'variant_name','Authorized Name':'authorized_name','DLL Identifier (Author)':'dll_id_author'})
works = works.rename(columns={'Title':'title','DLL Identifier (Work)':'dll_id_work','DLL Identifier (Author)': 'dll_id_author'})

# Prepare the lookup dictionaries of variant author names and titles
variant_to_authorized, title_to_work = utilities.prepare_dicts(authors,works)

# %% [markdown]
# ## Load the Models
#
# The following cells have two options. By default, they are set to load the versions of the models in repositories on HuggingFace. However, if you have cloned this repository and want to run the version that was created when you ran the fine-tuning notebooks (`python/fine_tune_distilmbert_author_local.ipynb` and `python/fine_tune_distilmbert_greek_local.ipynb`), then you can comment out the Huggingface cells and uncomment the local cells.

# %% [markdown]
# ### Greek-Latin Identification Model (HuggingFace Version)

# %%
# Path to the Greek-Latin Identification Model
greek_latin_model_repo = "sjhuskey/distilbert_multilingual_cased_greek_latin_classifier"


# Load the model and tokenizer from Hugging Face Hub
greek_latin_model = DistilBertForSequenceClassification.from_pretrained(greek_latin_model_repo)
# Move the model to the appropriate device
greek_latin_model.to(device)
# Load the tokenizer
greek_latin_tokenizer = DistilBertTokenizerFast.from_pretrained(greek_latin_model_repo)

print("Model and tokenizer loaded successfully!")
# Verify label mappings
label2id = greek_latin_model.config.label2id
id2label = greek_latin_model.config.id2label

print("Label-to-ID Mapping:", label2id)
print("ID-to-Label Mapping:", id2label)
# Out:
# config.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Model and tokenizer loaded successfully!
# Label-to-ID Mapping: {'Greek': 0, 'Latin': 1}
# ID-to-Label Mapping: {0: 'Greek', 1: 'Latin'}

# %% [markdown]
# ### Greek-Latin Identification Model (Local)
#
# If you choose this option, be sure to build the model first by running the notebook at `python/fine_tune_distilmbert_greek_local.ipynb` and uncomment the code in the next cell.

# %%
# # Path to the Greek-Latin Identification Model
# local_greek_model_path = "../greek"

# # Load the model and tokenizer from Hugging Face Hub
# greek_latin_model = DistilBertForSequenceClassification.from_pretrained(local_greek_model_path)
# # Move the model to the appropriate device
# greek_latin_model.to(device)
# # Load the tokenizer
# greek_latin_tokenizer = DistilBertTokenizerFast.from_pretrained(local_greek_model_path)

# print("Model and tokenizer loaded successfully!")
# # Verify label mappings
# label2id = greek_latin_model.config.label2id
# id2label = greek_latin_model.config.id2label

# print("Label-to-ID Mapping:", label2id)
# print("ID-to-Label Mapping:", id2label)

# %% [markdown]
# ### Author Reconciliation Model

# %%
# Path to Author Reconciliation Model
author_matching_repo = 'sjhuskey/distilbert_multilingual_cased_latin_author_identifier'

# Load the model for author reconciliation
author_matching = AutoModelForSequenceClassification.from_pretrained(author_matching_repo)
# Move the model to the appropriate device
author_matching.to(device)
# Load the tokenizer for author reconciliation
author_matching_tokenizer = AutoTokenizer.from_pretrained(author_matching_repo)

print("Author Reconciliation Model loaded successfully!")

# Verify label mappings
label2id = author_matching.config.label2id
id2label = author_matching.config.id2label

print("Label-to-ID Mapping:", label2id)
print("ID-to-Label Mapping:", id2label)
# Out:
# config.json:   0%|          | 0.00/124k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/551M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Author Reconciliation Model loaded successfully!
# Label-to-ID Mapping: {'A1868': 0, 'A1870': 1, 'A2181': 2, 'A2491': 3, 'A2492': 4, 'A2493': 5, 'A2494': 6, 'A2495': 7, 'A2508': 8, 'A2755': 9, 'A2868': 10, 'A2870': 11, 'A2871': 12, 'A2872': 13, 'A2873': 14, 'A2874': 15, 'A2875': 16, 'A2876': 17, 'A2877': 18, 'A2878': 19, 'A2879': 20, 'A2880': 21, 'A2881': 22, 'A2882': 23, 'A2883': 24, 'A2884': 25, 'A2885': 26, 'A2886': 27, 'A2887': 28, 'A2888': 29, 'A2889': 30, 'A2890': 31, 'A2891': 32, 'A2892': 33, 'A2893': 34, 'A2894': 35, 'A2895': 36, 'A2896': 37, 'A2897': 38, 'A2898': 39, 'A2901': 40, 'A2902': 41, 'A2903': 42, 'A2904': 43, 'A2905': 44, 'A2906': 45, 'A2907': 46, 'A2908': 47, 'A2909': 48, 'A2910': 49, 'A2911': 50, 'A2912': 51, 'A2913': 52, 'A2914': 53, 'A2915': 54, 'A2916': 55, 'A2917': 56, 'A2918': 57, 'A2919': 58, 'A2920': 59, 'A2921': 60, 'A2922': 61, 'A2923': 62, 'A2924
'A3114': 236, 'A3115': 237, 'A3116': 238, 'A3117': 239, 'A3118': 240, 'A3119': 241, 'A3120': 242, 'A3121': 243, 'A3122': 244, 'A3123': 245, 'A3124': 246, 'A3125': 247, 'A3126': 248, 'A3128': 249, 'A3129': 250, 'A3130': 251, 'A3131': 252, 'A3132': 253, 'A3133': 254, 'A3134': 255, 'A3135': 256, 'A3136': 257, 'A3137': 258, 'A3138': 259, 'A3139': 260, 'A3140': 261, 'A3141': 262, 'A3142': 263, 'A3143': 264, 'A3144': 265, 'A3145': 266, 'A3146': 267, 'A3147': 268, 'A3148': 269, 'A3149': 270, 'A3150': 271, 'A3151': 272, 'A3152': 273, 'A3153': 274, 'A3154': 275, 'A3155': 276, 'A3156': 277, 'A3157': 278, 'A3158': 279, 'A3161': 280, 'A3162': 281, 'A3165': 282, 'A3168': 283, 'A3169': 284, 'A3170': 285, 'A3171': 286, 'A3172': 287, 'A3173': 288, 'A3174': 289, 'A3175': 290, 'A3176': 291,  ...
# ID-to-Label Mapping: {0: 'A1868', 1: 'A1870', 2: 'A2181', 3: 'A2491', 4: 'A2492', 5: 'A2493', 6: 'A2494', 7: 'A2495', 8: 'A2508', 9: 'A2755', 10: 'A2868', 11: 'A2870', 12: 'A2871', 13: 'A2872', 14: 'A2873', 15: 'A2874', 16: 'A2875', 17: 'A2876', 18: 'A2877', 19: 'A2878', 20: 'A2879', 21: 'A2880', 22: 'A2881', 23: 'A2882', 24: 'A2883', 25: 'A2884', 26: 'A2885', 27: 'A2886', 28: 'A2887', 29: 'A2888', 30: 'A2889', 31: 'A2890', 32: 'A2891', 33: 'A2892', 34: 'A2893', 35: 'A2894', 36: 'A2895', 37: 'A2896', 38: 'A2897', 39: 'A2898', 40: 'A2901', 41: 'A2902', 42: 'A2903', 43: 'A2904', 44: 'A2905', 45: 'A2906', 46: 'A2907', 47: 'A2908', 48: 'A2909', 49: 'A2910', 50: 'A2911', 51: 'A2912', 52: 'A2913', 53: 'A2914', 54: 'A2915', 55: 'A2916', 56: 'A2917', 57: 'A2918', 58: 'A2919', 59: 'A2920', 60: 'A2921', 61: 'A2922', 62: 'A2923', 63: 'A2924', 64: 'A2925', 65: 'A2926', 66: 'A2927', 67: 'A2928', 68: 'A2929', 69: 'A2930', 70: 'A2931', 71: 'A2932', 72: 'A2933', 73: 'A2934', 74: 'A2935', 75: 'A2936', 76: 'A2937', 77: 'A2938', 78: 'A2939', 79: 'A2940', 80: 'A2941', 81: 'A2942', 82: 'A2943', 83: 'A2944', 84: 'A2945', 85: 'A2946', 86: 'A2947', 87: 'A2948', 88: 'A2949', 89: 'A2950', 90: 'A2952', 91: 'A2953', 92: 'A2954', 93: 'A2956', 94: 'A2957', 95: 'A2958', 96: 'A2959', 97: 'A2960', 98: 'A2961', 99: 'A2962', 100: 'A2963', 101: 'A2964', 102: 'A2965', 103: 'A2966', 104: 'A2967', 105: 'A2968', 106: 'A2969', 107: 'A2970', 108: 'A2972', 109: 'A2973', 110: 'A2974', 111: 'A2975', 112: 'A2976', 113: 'A2977', 114: 'A2978', 115: 'A2979', 116: 'A2982', 117: 'A2983', 118: 'A2984', 119: 'A2985', 120: 'A2986', 121: 'A2987', 122: 'A2988', 123: 'A2989', 124: 'A2990', 125: 'A2991', 126: 'A2992', 127: 'A2993', 128: 'A2994', 129: 'A2995', 130: 'A2996', 131: 'A2997', 132: 'A2998', 133: 'A2999', 134: 'A3000', 135: 'A3001', 136: 'A3002', 137: 'A3003', 138: 'A3004', 139: 'A3005', 140: 'A3006', 141: 'A3007', 142: 'A3008', 143: 'A3009', 144: 'A3010', 145: 'A3011', 146: 'A3012', 147: 'A3013', 148: 'A3014', 149: 'A3015', 150: 'A3016', 151: 'A3017', 152: 'A3018', 153: 'A3019', 154: 'A3020', 155: 'A3021', 156: 'A3022', 157: 'A3023', 158: 'A3024', 159: 'A3027', 160: 'A3028', 161: 'A3029', 162: 'A3030', 163: 'A3031', 164: 'A3032', 165: 'A3033', 166: 'A3034', 167: 'A3035', 168: 'A3036', 169: 'A3037', 170: 'A3038', 171: 'A3039', 172: 'A3040', 173: 'A3041', 174: 'A3042', 175: 'A3045', 176: 'A3048', 177: 'A3049', 178: 'A3050', 179: 'A3051', 180: 'A3054', 181: 'A3055', 182: 'A3056', 183: 'A3057', 184: 'A3058', 185: 'A3059', 186: 'A3060', 187: 'A3061', 188: 'A3062', 189: 'A3063', 190: 'A3064', 191: 'A3065', 192: 'A3066', 193: 'A3067', 194: 'A3068', 195: 'A3069', 196: 'A3070', 197: 'A3071', 198: 'A3072', 199: 'A3073', 200: 'A3075', 201: 'A3076', 202: 'A3077', 203: 'A3078', 204: 'A3079', 205: 'A3080', 206: 'A3081', 207: 'A3082', 208: 'A3083', 209: 'A3085', 210: 'A3086', 211: 'A3087', 212: 'A3088', 213: 'A3089', 214: 'A3090', 215: 'A3091', 216: 'A3093', 217: 'A3094', 218: 'A3095', 219: 'A3096', 220: 'A3097', 221: 'A3098', 222: 'A3099', 223: 'A3100', 224: 'A3101', 225: 'A3102', 226: 'A3104', 227: 'A3105', 228: 'A3106', 229: 'A3107', 230: 'A3108', 231: 'A3109', 232: 'A3110', 233: 'A3111', 234: 'A3112', 235: 'A3113', 236: 'A3114', 237: 'A3115', 238: 'A3116', 239: 'A3117', 240: 'A3118', 241: 'A3119', 242: 'A3120', 243: 'A3121', 244: 'A3122', 245: 'A3123', 246: 'A3124', 247: 'A3125', 248: 'A3126', 249: 'A3128', 250: 'A3129', 251: 'A3130', 252: 'A3131', 253: 'A3132', 254: 'A3133', 255: 'A3134', 256: 'A3135', 257: 'A3136', 258: 'A3137', 259: 'A3138', 260: 'A3139', 261: 'A3140', 262: 'A3141', 263: 'A3142', 264: 'A3143', 265: 'A3144', 266: 'A3145', 267: 'A3146', 268: 'A3147', 269: 'A3148', 270: 'A3149', 271: 'A3150', 272: 'A3151', 273: 'A3152', 274: 'A3153', 275: 'A3154', 276: 'A3155', 277: 'A3156', 278: 'A3157', 279: 'A3158', 280: 'A3161', 281: 'A3162', 282: 'A3165', 283: 'A3168', 284: 'A3169', 285: 'A3170', 286: 'A3171', 287: 'A3172', 288: 'A3173', 289: 'A3174', 290: 'A3175', 291: 'A3176',  ...

# %% [markdown]
# ### Author Reconciliation Model (Local)
#
# If you choose this option, be sure to build the model first by running the notebook at `python/fine_tune_distilmbert_author_local.ipynb` and uncomment the code in the next cell.

# %%
# # Path to Author Reconciliation Model
# local_author_model_path = "../authors"

# # Load the model for author reconciliation
# author_matching = AutoModelForSequenceClassification.from_pretrained(local_author_model_path)
# # Move the model to the appropriate device
# author_matching.to(device)
# # Load the tokenizer for author reconciliation
# author_matching_tokenizer = AutoTokenizer.from_pretrained(local_author_model_path)

# print("Author Reconciliation Model loaded successfully!")

# # Verify label mappings
# label2id = author_matching.config.label2id
# id2label = author_matching.config.id2label

# print("Label-to-ID Mapping:", label2id)
# print("ID-to-Label Mapping:", id2label)

# %% [markdown]
# ## Metadata Processing Functions
#
# The following functions are necessary for providing comprehensible output from the models' inferences.
#
# ### Greek-Latin Identification
#
# - `classify_author_language`: Tokenizes authors' names from the incoming metadata records and passes them to the Greek-Latin Identification model. Returns the predicted label ("Greek" or "Latin") and the confidence score for the prediction.
# - `classify_and_split_by_language`: Returns three Pandas dataframes—`classified_df`, with all results from the Greek-Latin Identification model; `greek_df`, with results labeled "Greek"; `latin_df`, with results labeled "Latin". The latter will be the input for the Author Reconciliation model.
#
# Note that these functions process one input at a time. There is potential for speeding up the process by batching the inputs.

# %%
# Language Classification Functions
def classify_author_language(input_author):
    """Classify the author's language as Greek or Latin using the fine-tuned model."""
    if not isinstance(input_author, str):
        return "Unknown", 0.0

    # Tokenize and encode the input author name
    inputs = greek_latin_tokenizer(input_author, return_tensors="pt", truncation=True, padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = greek_latin_model(**inputs)
    logits = outputs.logits.detach().cpu()

    # Apply softmax to logits to get probabilities
    probabilities = F.softmax(logits, dim=-1).numpy()
    predicted_class = probabilities.argmax(axis=-1)[0]
    confidence = probabilities.max()  # Highest probability

    # Use the id2label mapping for label names
    predicted_label = greek_latin_model.config.id2label[predicted_class]
    print(f"Language Classification: {input_author} -> {predicted_label} (Confidence: {confidence:.4f})")

    return predicted_label, confidence

def classify_and_split_by_language(processed_df):
    """Classify authors as Greek or Latin, add language info, and split the dataframe."""
    language_results = []

    for _, row in processed_df.iterrows():
        input_author = row["author"]

        # Perform language classification
        author_language, language_confidence = classify_author_language(input_author)

        # Add the results to a new row while preserving existing data
        updated_row = {
            **row,  # Include all original columns
            "language": author_language,
            "language_confidence": language_confidence,
        }
        language_results.append(updated_row)

    # Create a dataframe with the updated rows
    classified_df = pd.DataFrame(language_results)

    # Split the dataframe into Greek and Latin subsets
    greek_df = classified_df[classified_df["language"] == "Greek"].reset_index(drop=True)
    latin_df = classified_df[classified_df["language"] == "Latin"].reset_index(drop=True)

    return classified_df, greek_df, latin_df

# %% [markdown]
# ### Author Reconciliation Functions
#
# - `distilbert_author_match`: Tokenizes authors' names and passes them to the Author Reconciliation model. Returns the predicted label ("DLL ID") and the confidence score for the prediction.
# - `process_metadata`: Manages input and output for the Author Reconciliation model. Returns a dataframe with the results of the inference run.
#
# Note that these functions process one input at a time. There is potential for speeding up the process by batching the inputs.

# %%
# Author Reconciliation Functions
def distilbert_author_match(input_author):
    if not isinstance(input_author, str):
        return None, 0.0

    inputs = author_matching_tokenizer(input_author, return_tensors="pt", truncation=True, padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = author_matching(**inputs)
    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=-1).item()
    confidence = torch.softmax(logits, dim=-1).max().item()

    predicted_author_id = author_matching.config.id2label[predicted_class]
    for variant, author_info in variant_to_authorized.items():
        if author_info["author_id"] == predicted_author_id:
            return author_info, confidence
    return None, 0.0

def process_metadata(input_df):
    """Process input dataframe and match metadata."""
    results = []

    for _, row in input_df.iterrows():
        input_author_original = row["author"]
        input_author_normalized = utilities.normalize_author_name(input_author_original)
        print(f'Processing: {input_author_original}')

        # Author Matching
        distilbert_author, confidence = distilbert_author_match(input_author_original)
        if distilbert_author is None:
            print(f"No match found for author: {input_author_original}")
            continue
        # Collect Results
        results.append({
            "author": input_author_original,
            "normalized_author": input_author_normalized,
            "distilbert_author": distilbert_author,
            "confidence": confidence
        })
        print(f"Matched author: {distilbert_author}")

    return pd.DataFrame(results)

# %% [markdown]
# ## Greek-Latin Identification Inferencing
#
# The next few cells have to do with running the Greek-Latin Identification model on the data downloaded from the HathiTrust Digital Library. The original data file is in `../data/1908698974-1722799169.txt`. The cleaned and deduplicated version is at `../data/hathi2.csv`.

# %% [markdown]
# ### Load the Data

# %%
# Load preprocessed, deduplicated hathi2.csv
input_df = pd.read_csv('../data/hathi2.csv', encoding='utf-8', quotechar='"') 
# Further clean the data by filling missing values with "Unknown"
input_df = utilities.clean_input(input_df)

# %% [markdown]
# ### Start the emissions tracker for the Greek-Latin Identification model
#
# The `EmissionsTracker` from `codecarbon` will track the energy used by the Greek-Latin Identification model during inferencing.

# %%
# Set up codecarbon's EmissionsTracker for the Greek-Latin Identification Model
tracker = EmissionsTracker(
    output_dir="../logs",
    output_file="greek_latin_identification_inference_emissions_log.csv"
)
tracker.start()
# Out:
# [codecarbon INFO @ 14:45:25] [setup] RAM Tracking...
# [codecarbon INFO @ 14:45:25] [setup] GPU Tracking...
# [codecarbon INFO @ 14:45:25] No GPU found.
# [codecarbon INFO @ 14:45:25] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:45:25] No CPU tracking mode found. Falling back on CPU constant mode.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [codecarbon WARNING @ 14:45:25] We saw that you have a Apple M4 Pro but we don't know it. Please contact us.
# [codecarbon INFO @ 14:45:25] CPU Model on constant consumption mode: Apple M4 Pro
# [codecarbon INFO @ 14:45:25] >>> Tracker's metadata:
# [codecarbon INFO @ 14:45:25]   Platform system: macOS-15.5-arm64-arm-64bit
# [codecarbon INFO @ 14:45:25]   Python version: 3.10.9
# [codecarbon INFO @ 14:45:25]   CodeCarbon version: 2.2.2
# [codecarbon INFO @ 14:45:25]   Available RAM : 24.000 GB
# [codecarbon INFO @ 14:45:25]   CPU count: 12
# [codecarbon INFO @ 14:45:25]   CPU model: Apple M4 Pro
# [codecarbon INFO @ 14:45:25]   GPU count: None
# [codecarbon INFO @ 14:45:25]   GPU model: None

# %% [markdown]
# ### Set up a Timer for the Greek-Latin Identification Inferencing

# %%
start_time = time.time()

# %% [markdown]
# ### Begin Inferencing with the Greek-Latin Identification Model

# %%
# Signal the start of the metadata processing
print('Classifying authors as Greek or Latin …')
# Use the classify_and_split_by_language() function to run the Greek-Latin classification model
classified_df, greek_df, latin_df = classify_and_split_by_language(input_df)
# Signal the end of the Greek-Latin classification
print("Done with classification.")
# Out:
# Classifying authors as Greek or Latin …
# Language Classification: Du Creux, François, 1596?-1666. -> Latin (Confidence: 1.0000)
# Language Classification: Meyer, Ernst H. F. 1791-1858. -> Latin (Confidence: 1.0000)
# Language Classification: Laet, Joannes de, 1593-1649. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius -> Latin (Confidence: 0.9999)
# Language Classification: Unknown -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Kircher, Athanasius, 1602-1680 -> Latin (Confidence: 1.0000)
# Language Classification: Hincmar, Archbishop of Reims, approximately 806-882 -> Latin (Confidence: 1.0000)
# Language Classification: Acosta, José de, 1540-1600, -> Latin (Confidence: 1.0000)
# Language Classification: Lessius, Leonardus, 1554-1623 -> Latin (Confidence: 1.0000)
# Language Classification: Riccioli, Giovanni Battista, 1598-1671, -> Latin (Confidence: 1.0000)
# Language Classification: Guazzo, Francesco Maria, -> Latin (Confidence: 1.0000)
# Language Classification: Kircher, Athanasius, 1602-1680. -> Latin (Confidence: 1.0000)
# Language Classification: Mersenne, Marin, 1588-1648, -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Roothaan, Joannes Philippus, 1785-1853 -> Latin (Confidence: 1.0000)
# Language Classification: Arrian. -> Greek (Confidence: 0.9949)
# Language Classification: Euclid, -> Greek (Confidence: 0.9991)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Alvares, Manuel, 1526-1583. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Huygens, Constantijn, 1596-1687 -> Latin (Confidence: 1.0000)
# Language Classification: Nieremberg, Juan Eusebio, 1595-1658. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Reiske, Johann Jacob, 1716-1774. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Boethius, -524. -> Latin (Confidence: 1.0000)
# Language Classification: Prosper, of Aquitaine, Saint, approximately 390-approximately 463. -> Latin (Confidence: 1.0000)
# Language Classification: Vitruvius Pollio. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Latin (Confidence: 1.0000)
# Language Classification: Torsellino, Orazio, 1545-1599. -> Latin (Confidence: 1.0000)
# Language Classification: Juvencus, Caius Vettius Aquilinus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Hyginus, Gromaticus. -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Rostowski, Stanislaw, 1711-1784. -> Latin (Confidence: 1.0000)
# Language Classification: Valerius Flaccus, Gaius, active 1st century. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Duns Scotus, John, ca. 1266-1308. -> Latin (Confidence: 1.0000)
# Language Classification: Navarrete, Jean André, 1730-1811. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Commodianus. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Copernicus, Nicolaus, 1473-1543 -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Herodotus. -> Greek (Confidence: 0.9991)
# Language Classification: Celsus, Aulus Cornelius. -> Greek (Confidence: 0.9983)
# Language Classification: Nonius Marcellus, active 4th century. -> Latin (Confidence: 1.0000)
# Language Classification: Bacon, Roger, 1214?-1294. -> Latin (Confidence: 1.0000)
# Language Classification: Nakatenus, Wilhelm, 1617-1682. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Latin (Confidence: 1.0000)
# Language Classification:
kWh. RAM Power : 9.000000000000002 W
# [codecarbon INFO @ 14:47:31] Energy consumed for all CPUs : 0.001486 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:47:31] 0.001801 kWh of electricity used since the beginning.
# Execution time: 125.89 seconds
# Estimated CO2 emissions for training: 0.0008525679137120403 kg

# %% [markdown]
# ### Results of the Greek-Latin Identification Process

# %%
print(f"Number of rows in the Greek dataframe: {len(greek_df)}")
print(f"Number of rows in the Latin dataframe: {len(latin_df)}")
print(f"The classification step removed {len(classified_df)-len(latin_df)} records.")
# Out:
# Number of rows in the Greek dataframe: 1477
# Number of rows in the Latin dataframe: 13446
# The classification step removed 1477 records.

# %%
# Save the results to CSV files
classified_df.to_csv("../output/classified_metadata.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
greek_df.to_csv("../output/greek_authors.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
latin_df.to_csv("../output/latin_authors.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)

# %%
# Print unique authors in the Greek dataframe for verification
for author in greek_df['author'].unique():
    print(author)
# Out:
# Arrian.
# Euclid,
# Herodotus.
# Celsus, Aulus Cornelius.
# Anacreon
# John Chrysostom, Saint, -407
# Clement, of Alexandria, Saint, approximately 150-approximately 215
# Herodotus
# Nemesius, Bp. of Emesa
# Pindar
# Theocritus.
# Xenophon
# Catherine, of Alexandria, Saint.
# Aristophanes.
# Index librorum prohibitorum.
# Homer
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403.
# Euripides
# Philo, of Alexandria
# Plato.
# Plato
# Plotinus
# Demosthenes
# Plutarch.
# Homer.
# Theophrastus.
# Thucydides
# Epictetus
# Origen
# Celsus, Aulus Cornelius
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403
# Aristotle
# Archimedes.
# Dioscorides Pedanius, of Anazarbos
# Nicomachus, of Gerasa.
# Proclus, approximately 410-485
# Müller, K. W.
# Xenophon, of Ephesus
# Gregory, of Nyssa, Saint, approximately 335-approximately 394.
# Theocritus
# Sextus, Empiricus
# Philostratus, the Athenian, active 2nd century-3rd century
# Longus
# Stobaeus
# Apollonius, of Athens.
# Arrian
# Philo, of Byzantium
# Justin, Martyr, Saint
# Hippocrates
# Elias, of Nisibis, 975-1046
# Iamblichus, approximately 250-approximately 330.
# Anacreon.
# Lucian, of Samosata
# Moczynski, P.
# Isocrates.
# Proclus, approximately 410-485.
# Eusebius, of Caesarea, Bishop of Caesarea, approximately 260-approximately 340.
# Cleomedes.
# Orpheus.
# Pindar.
# Euclid.
# Aristotle.
# Choniates, Nicetas, ca. 1140-1213.
# Agathias, d. 582.
# Marcus Aurelius, Emperor of Rome, 121-180.
# Apollodorus.
# Plemp, C. G.
# Artephius,
# Josephus, Flavius.
# Autolycus.
# Gregory, of Nazianzus, Saint
# Nemesius, Bp. of Emesa.
# Macarius, the Egyptian, Saint, active 4th century
# Hero, of Alexandria.
# Misset, E.,
# Galen
# Gregory, of Nyssa, Saint, ca. 335-ca. 394.
# Tartaret, Pierre, 15th cent.
# Hierocles, of Alexandria, active 430.
# Alexander, of Aphrodisias.
# Marcus Aurelius, Emperor of Rome, 121-180
# Hermogenes, 2nd cent
# Hierocles, of Alexandria, fl. 430
# Alexander, of Aphrodisias
# Themistius
# Michael, of Ephesus
# Sophonias
# Simplicius, of Cilicia.
# Pseudo-Dionysius, the Areopagite
# Philoponus, John, 6th cent
# Apollonio à Iesu
# Comnena, Anna, 1083-
# Orpheus (Greek mythological character)
# Prodromus, Theodore.
# Aristides Quintilianus.
# Philodemus, ca. 110-ca. 40 B.C.
# Terentianus Maurus.
# Iamblichus, ca. 250-ca. 330.
# Anastasius, the Librarian, approximately 810-approximately 878.
# Panyasis, fl. 500-450 B.C.
# Hipócrates.
# Galeno.
# Celso, Aulo Cornelio.
# Diogenes Laercio.
# Pistoris, Jean.
# Hipócrates
# Polibio
# Yuhanna Ibn Serapion, s. 9
# Josefo, Flavio, ca. 37-ca. 100.
# L'Écluse, Charles de.
# Apolonio de Pérgamo.
# Pseudo Dionisio Areopagita.
# Euclides.
# Artephius.
# Opiano de Apamea.
# López de Palacios Rubios, Juan
# Aristóteles, 384-322 a.C.
# Clemente, Juan.
# Teofrasto.
# Apianus, Petrus, 1482-1535.
# Plukenet, Leonard
# Devoti, Joannis.
# Apollonius, Levinus.
# Arato de Soles.
# Galeno
# Ptolomeo, Claudio.
# Ptolomeo, Claudio
# Solino, Cayo Julio
# Estrabón
# Clemente de Alejandría.
# Orígenes.
# Isidoro de Pelusio, Santo.
# Filóstrato, Flavio, ca. 170-ca. 249
# Nicephorus Callistus, ca. 1256-1335.
# Paulus Aegineta
# Paulus Aegineta.
# Gregorio de Nisa, Santo, ca. 335-ca. 394.
# Filopón, Juan.
# Doc, Jean, Obispo de Laon
# Eusebio de Cesarea, Obispo de Cesarea, ca. 265-ca. 340
# Ireneo, Santo, Obispo de Lyon
# Plotino.
# Epifanio, Santo, Obispo de Constancia, ca. 315-403.
# Cirilo, Santo, Patriarca de Alejandría, 376?-444.
# Juan Damasceno, Santo, 676-ca. 750.
# Teodosio de Tripoli.
# Juan Crisóstomo, Santo, ca. 344-407
# Justino, Santo, 100?-165?
# Abdias, Obispo de Babilonia.
# Atanasio, Santo, ca. 297-373.
# Dionysius Cisterciensis.
# Dioscórides.
# Berosio.
# Opiano.
# Basilio, Santo, Obispo de Cesarea, 329?-379.
# Juliano, Emperador de Roma, 331-363.
# Filón de Alejandria, ca. 25 a.C.-ca. 50
# Diodoro Sículo.
# Platón, ca. 427-348 a.C.
# Solís, Feliciano de.
# Herodoto, 484-425 a. C.
# Constantino, VII, Porfirogéneta, Emperador de Bizancio.
# Juan Crisóstomo, Santo, ca. 344-407.
# Estrabón.
# Optato, Santo, s.4.
# Magalhaes, Cosmé.
# Filón de Alejandria, ca. 25 a.C.-ca. 50.
# Johannes Philoponus.
# Monachus, Antonius.
# Sosa, Mateo de.
# Gregorio Nacianceno, Santo, 330-390.
# Diana, Antonino (CC.RR.MM.)
# Antonini, Mario.
# Gregorio Taumaturgo, Santo, ca. 213-270.
# Fattolillus, Johannes Baptista Carmen.
# Ireneo, Santo, Obispo de Lyon.
# Machicado y Rosillo, Manuel.
# Arquímedes, (287-212 a.C.)
# Procopio de Gaza, ca. 465-ca. 528
# Juan Clímaco, Santo.
# Eusebio de Cesarea, Obispo de Cesarea, ca. 265-ca. 340.
# Amato, Antonino de.
# Hipocrates.
# Tucídides, ca. 460-ca. 400 a. C.
# Diogenes Laercio
# Rebello, Fernando (S.I.)
# Arriano, Flavio
# Constantino Africano.
# Aecio de Amida
# Theodoretus, Obispo de Cyrrhus,  393-460.
# Proclo, 412-485
# Euclides
# Cirilo, Santo, Patriarca de Alejandría, 376?-444
# Alejandro de Afrodisia
# Herón, de Alejandría
# Arquímedes, 287-212 a.C.
# Jesuitas.
# De Marinis, Donato Antonio.
# Artemidoro.
# Herón, de Alejandría.
# Albumasar.
# Prudencio Clemente, Aurelio.
# Efren de Nisibis, Santo, 303-373.
# Eliano, Claudio.
# Pseudo Dionisio Areopagita
# Apolodoro de Atenas.
# Buiza y Llamazares, Juan de.
# Basilio I, Emperador de Bizancio, ca. 867-886.
# Boskierus Hannonius, Philippus
# Comnena, Anna.
# Apolonio de Rodas.
# Quinto de Esmirna.
# Basilius, Valentinus.
# Hierocles Platónico, s.5 d.C.
# Proclo, 412-485.
# Magnen, Jean Chrysostome.
# Temistio.
# Homero.
# Luciano de Samosata.
# Peramás, José Manuel, (1732-1793)
# Dion Casio
# Yamblico.
# Tucídides ca. 460-ca. 400 a. C.
# Epo, Boetius.
# Jesuitas
# Hostus, Mathaeus.
# Heródoto, 484-425 a. C.
# Esopo, 620?-560? a.C.
# Polibio.
# Diógenes Laercio.
# Hesiodo.
# Bartelon, Pantaléon
# Diomedes.
# Ateneo de Náucratis
# Contador de Argote, Jeronimo.
# Jenofonte, ca. 430 a.C-ca. 354 a.C
# Alexander Trallianus.
# Oribasio.
# Teodoreto, Obispo de Ciro.
# Nicetas Acominatus Choniates.
# Herodiano, 170-240.
# Clemente I, Papa.
# Doc, Jean, Obispo de Laon.
# Prat de Saba, Onofre (S.I.)
# Aristoteles, 384-322 a.C.
# Mosconius, Isidorus.
# Mishna.
# Epicteto.
# Areteo de Capadocia.
# Celso, Aulo Cornelio
# Apiano.
# Píndaro, ca. 518-ca. 438 a. C.
# Palladius Florentinus
# Origenes.
# Zacarias, Obispo de Crisópolis.
# Pamphylus, Jacobus
# Philostorgius.
# Meneses y Pedrosa, Fernando de.
# Plutarco, ca. 46-ca. 119.
# Simplicio.
# Procopio de Cesárea.
# Anacreonte.
# Epo, Boetius
# Procopio de Cesarea.
# Agathias Scholasticus, 536-582.
# Comnena, Anna, 1083-1148.
# Pachymeres, George, 1242-ca. 1310.
# Juan VI, Cantacuceno, Emperador de Bizancio, 1292-1383.
# Genesios, Ioseph, fl. 912-959.
# Nicolas de Damasco.
# HIPOCRATES.
# Dión Casio.
# Lerma, Cosme de, (O.P.)
# Apiano
# Deodato, Claudio.
# Manuel de la Concepción, (O.SS.T.)
# Aristófanes.
# Dionisio de Halicarnaso, ca. 60-5 a.C.
# Musaeus, S. V d. de J. C.
# Polieno.
# Heliodoro.
# Heliodoro
# Asclepiadeus, Androphilus.
# Marco Aurelio, Emperador de Roma, 121-180
# Arethas, Arzobispo de Cesarea.
# Demetrius Pepagomenus, s.13.
# Ateneo de Naúcratis.
# Pausanias.
# Theophilus, G.
# Aelianus, Tacticus, 2nd cent.
# Atilius Fortunatianus, 4th cent.
# Joannes Kyriotes, called Geometres, 10th cent.
# Horapollo.
# Lydus, Johannes.
# Pindarus.
# Dio Chrysostomus.
# Arrianus, Flavius.
# Paulus, Aegineta.
# Némethy, Geza.
# Homerus.
# Theodorus, Flavius Mallius, ca. 350-410.
# Comnena, Anna, b. 1083.
# Panyassis Halicarnassensis.
# Callimachus.
# Epiphanius, Saint, Bishop of Constantia in Cyprus, ca. 310-403.

# %% [markdown]
# Those results look pretty solid.

# %% [markdown]
# ## Author Reconciliation Inferencing
#
# The remaining cells take the `latin_df` output from the Greek-Latin Identification model and submit it to the Author Reconciliation model for inferencing.

# %% [markdown]
# ### Set up the emissions tracker for the Author Identification model
#
# This, too, uses the `EmissionsTracker` from `codecarbon`.

# %%
# Set up CodeCarbon's EmissionsTracker
tracker = EmissionsTracker(
    output_dir="../logs",
    output_file="author_reconciliation_inference_emissions_log.csv"
)
tracker.start()
# Out:
# [codecarbon INFO @ 14:47:31] [setup] RAM Tracking...
# [codecarbon INFO @ 14:47:31] [setup] GPU Tracking...
# [codecarbon INFO @ 14:47:31] No GPU found.
# [codecarbon INFO @ 14:47:31] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:47:31] No CPU tracking mode found. Falling back on CPU constant mode.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [codecarbon WARNING @ 14:47:31] We saw that you have a Apple M4 Pro but we don't know it. Please contact us.
# [codecarbon INFO @ 14:47:31] CPU Model on constant consumption mode: Apple M4 Pro
# [codecarbon INFO @ 14:47:31] >>> Tracker's metadata:
# [codecarbon INFO @ 14:47:31]   Platform system: macOS-15.5-arm64-arm-64bit
# [codecarbon INFO @ 14:47:31]   Python version: 3.10.9
# [codecarbon INFO @ 14:47:31]   CodeCarbon version: 2.2.2
# [codecarbon INFO @ 14:47:31]   Available RAM : 24.000 GB
# [codecarbon INFO @ 14:47:31]   CPU count: 12
# [codecarbon INFO @ 14:47:31]   CPU model: Apple M4 Pro
# [codecarbon INFO @ 14:47:31]   GPU count: None
# [codecarbon INFO @ 14:47:31]   GPU model: None

# %% [markdown]
# ### Start a timer for Author Identification Inferencing

# %%
start_time = time.time()

# %% [markdown]
# ### Begin Inferencing with the Author Identification Model
#
# The following cell uses the `process_metadata()` function defined earlier to send data to the model for inferencing.

# %%
output_df = process_metadata(latin_df)
print("Done with processing authors.")
# Out:
# Processing: Du Creux, François, 1596?-1666.
# Matched author: {'authorized_name': 'graux, charles henri, 1852-1882', 'author_id': 'A3249'}
# Processing: Meyer, Ernst H. F. 1791-1858.
# Matched author: {'authorized_name': 'meyer, wilhelm, 1845-1917', 'author_id': 'A6252'}
# Processing: Laet, Joannes de, 1593-1649.
# Matched author: {'authorized_name': 'lawrence, of novara', 'author_id': 'A5070'}
# Processing: Caesar, Julius
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Drexel, Jeremias, 1581-1638,
# Matched author: {'authorized_name': 'dorpius, martinus, 1485-1525', 'author_id': 'A4045'}
# Processing: Kircher, Athanasius, 1602-1680
# Matched author: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Processing: Hincmar, Archbishop of Reims, approximately 806-882
# Matched author: {'authorized_name': 'hincmar, archbishop of reims', 'author_id': 'A5135'}
# Processing: Acosta, José de, 1540-1600,
# Matched author: {'authorized_name': 'acosta, josé de, 1540-1600', 'author_id': 'A5598'}
# Processing: Lessius, Leonardus, 1554-1623
# Matched author: {'authorized_name': 'lessing, gotthold ephraim, 1729-1781', 'author_id': 'A3929'}
# Processing: Riccioli, Giovanni Battista, 1598-1671,
# Matched author: {'authorized_name': 'ricci, matteo, 1552-1610', 'author_id': 'A4121'}
# Processing: Guazzo, Francesco Maria,
# Matched author: {'authorized_name': 'giovio, benedetto, 1471-1545', 'author_id': 'A5993'}
# Processing: Kircher, Athanasius, 1602-1680.
# Matched author: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Processing: Mersenne, Marin, 1588-1648,
# Matched author: {'authorized_name': 'mersenne, marin, 1588-1648', 'author_id': 'A4211'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Kepler, Johannes, 1571-1630.
# Matched author: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Processing: Roothaan, Joannes Philippus, 1785-1853
# Matched author: {'authorized_name': 'heidenhain, friedrich jakob, 1845-1912', 'author_id': 'A3484'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Alvares, Manuel, 1526-1583.
# Matched author: {'authorized_name': 'alvares, manuel, 1526-1583', 'author_id': 'A6175'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Huygens, Constantijn, 1596-1687
# Matched author: {'authorized_name': 'huygens, christiaan, 1629-1695', 'author_id': 'A4138'}
# Processing: Nieremberg, Juan Eusebio, 1595-1658.
# Matched author: {'authorized_name': 'schweickhofer, johannes', 'author_id': 'A4222'}
# Processing: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621.
# Matched author: {'authorized_name': 'longolius, christophorus, 1488-1522', 'author_id': 'A3945'}
# Processing: Reiske, Johann Jacob, 1716-1774.
# Matched author: {'authorized_name': 'reisch, emil, 1863-1933', 'author_id': 'A6268'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Boethius, -524.
# Matched author: {'authorized_name': 'boethius, -524', 'author_id': 'A5469'}
# Processing: Prosper, of Aquitaine, Saint, approximately 390-approximately 463.
# Matched author: {'authorized_name': 'prosper, of aquitaine, saint', 'author_id': 'A4899'}
# Processing: Vitruvius Pollio.
# Matched author: {'authorized_name': 'vitruvius pollio', 'author_id': 'A4853'}
# Processing: Thomas, Aquinas, Saint, 1225?-1274.
# Matched author: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Torsellino, Orazio, 1545-1599.
# Matched author: {'authorized_name': 'horatius romanus', 'author_id': 'A3205'}
# Processing: Juvencus, Caius Vettius Aquilinus.
# Matched author: {'authorized_name': 'juvencus, caius vettius aquilinus', 'author_id': 'A5223'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Hyginus, Gromaticus.
# Matched author: {'authorized_name': 'hyginus, gromaticus', 'author_id': 'A4606'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Rostowski, Stanislaw, 1711-1784.
# Matched author: {'authorized_name': 'morawski, kazimierz, 1852-1925', 'author_id': 'A3270'}
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: {'authorized_name': 'valerius flaccus, gaius', 'author_id': 'A4806'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Duns Scotus, John, ca. 1266-1308.
# Matched author: {'authorized_name': 'duns scotus, john, approximately 1266-1308', 'author_id': 'A5593'}
# Processing: Navarrete, Jean André, 1730-1811.
# Matched author: {'authorized_name': 'galilei, galileo', 'author_id': 'A4716'}
# Processing: Caesar, Julius.
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Commodianus.
# Matched author: {'authorized_name': 'commodianus', 'author_id': 'A5248'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Copernicus, Nicolaus, 1473-1543
# Matched author: {'authorized_name': 'copernicus, nicolaus, 1473-1543', 'author_id': 'A4141'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Nonius Marcellus, active 4th century.
# Matched author: {'authorized_name': 'nonius marcellus', 'author_id': 'A4349'}
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: {'authorized_name': 'bacon, roger, 1214?-1294', 'author_id': 'A4387'}
# Processing: Nakatenus, Wilhelm, 1617-1682.
# Matched author: {'authorized_name': 'institoris, heinrich, 1430-1505', 'author_id': 'A5676'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Gretser, Jakob, 1562-1625.
# Matched author: {'authorized_name': 'gretser, jakob, 1562-1625', 'author_id': 'A3957'}
# Processing: Palladius, Rutilius Taurus Aemilianus.
# Matched author: {'authorized_name': 'palladius, rutilius taurus aemilianus', 'author_id': 'A4315'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Huygens, Christiaan, 1629-1695.
# Matched author: {'authorized_name': 'huygens, christiaan, 1629-1695', 'author_id': 'A4138'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Caesar, Julius.
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Valerius Maximus.
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Silius Italicus, Tiberius Catius.
# Matched author: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Processing: Victor, Sextus Aurelius.
# Matched author: {'authorized_name': 'victor, sextus aurelius', 'author_id': 'A4936'}
# Processing: Callaghan, John, 1605-1654,
# Matched author: {'authorized_name': 'lynch, john, approximately 1599-approximately 1673', 'author_id': 'A3906'}
# Processing: Juvenal.
# Matched author: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Processing: Kircher, Athanasius, 1602-1680
# Matched author: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Processing: Claudianus, Claudius
# Matched author: {'authorized_name': 'claudianus, claudius', 'author_id': 'A4503'}
# Processing: Knabenbauer, Joseph, 1839-1911.
# Matched author: {'authorized_name': 'krahner, leopold, 1810-1884', 'author_id': 'A6102'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Florus, Lucius Annaeus.
# Matched author: {'authorized_name': 'florus, lucius annaeus', 'author_id': 'A5047'}
# Processing: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621.
# Matched author: {'authorized_name': 'longolius, christophorus, 1488-1522', 'author_id': 'A3945'}
# Processing: Suarez, Francisco, 1548-1617,
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Propertius, Sextus.
# Matched author: {'authorized_name': 'propertius, sextus', 'author_id': 'A4889'}
# Processing: Noceti, Carlo, 1694-1759.
# Matched author: {'authorized_name': "nobili, roberto de' 1577-1656", 'author_id': 'A3865'}
# Processing: Maffei, Giovanni Pietro, 1536?-1603.
# Matched author: {'authorized_name': 'maffei, giovanni pietro, 1536?-1603', 'author_id': 'A3869'}
# Processing: Thomas, Aquinas, Saint, 1225?-1274.
# Matched author: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Processing: Franchis, Francesco de.
# Matched author: {'authorized_name': 'negri, francesco, 1452-approximately 1523', 'author_id': 'A4289'}
# Processing: Pliny, the Elder
# Matched author: {'authorized_name': 'pliny, the elder', 'author_id': 'A5537'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Horatius, Romanus, fl. 1450.
# Matched author: {'authorized_name': 'horatius romanus', 'author_id': 'A3205'}
# Processing: Doni, Gio. Battista 1593 or 1594-1647
# Matched author: {'authorized_name': 'donizone, di canossa', 'author_id': 'A5326'}
# Processing: Viger, François, 1590-1647
# Matched author: {'authorized_name': 'victor, vitensis', 'author_id': 'A4782'}
# Processing: Lucas, Karl Wilhelm.
# Matched author: {'authorized_name': 'lucas, bishop of túy, -approximately 1249', 'author_id': 'A4371'}
# Processing: Portus, Aemilius, 1550-1614 or 1615
# Matched author: {'authorized_name': 'alanus, de insulis', 'author_id': 'A4458'}
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: {'authorized_name': 'muret, marc-antoine, 1526-1585', 'author_id': 'A3873'}
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: {'authorized_name': 'muret, marc-antoine, 1526-1585', 'author_id': 'A3873'}
# Processing: Klausen, Rudolf Heinrich, 1807-1840.
# Matched author: {'authorized_name': 'schöll, rudolf, 1844-1893', 'author_id': 'A5974'}
# Processing: Martin, Bernard, 1574-1639.
# Matched author: {'authorized_name': 'andreas, bernard, active 1500', 'author_id': 'A4126'}
# Processing: Wesseling, Petrus, 1692-1764
# Matched author: {'authorized_name': 'wessely, carl, 1860-1931', 'author_id': 'A3348'}
# Processing: Hanow, Rudolf, 1806-1871.
# Matched author: {'authorized_name': 'schottennius, hermannus', 'author_id': 'A5620'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Curtius Rufus, Quintus
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Florus, Lucius Annaeus
# Matched author: {'authorized_name': 'florus, lucius annaeus', 'author_id': 'A5047'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Burchard, Johann Friedrich Wilhelm,
# Matched author: {'authorized_name': 'burchard, von reichenau', 'author_id': 'A4975'}
# Processing: Vater, Johann Severin, 1771-1826
# Matched author: {'authorized_name': 'pufendorf, samuel, freiherr von, 1632-1694', 'author_id': 'A3714'}
# Processing: Henrichsen, Rudolf Johann Frederik, 1800-1871.
# Matched author: {'authorized_name': 'schmidt, wilhelm, 1862-1905', 'author_id': 'A6277'}
# Processing: Lauer, Julius Franz, 1819-1850.
# Matched author: {'authorized_name': 'frey, joseph, 1834-1910', 'author_id': 'A6205'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Groke, Th. Wilhelm.
# Matched author: {'authorized_name': 'gemoll, wilhelm, 1850-1934', 'author_id': 'A5660'}
# Processing: Butler, Samuel, 1774-1839
# Matched author: {'authorized_name': 'cowley, abraham, 1618-1667', 'author_id': 'A4034'}
# Processing: Katrares, Johannes, 14th cent.
# Matched author: {'authorized_name': 'john, canonicus, active 14th century', 'author_id': 'A3706'}
# Processing: Augustine, of Hippo, Saint, 354-430.
# Matched author: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Processing: Caesar, Julius
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Caesar, Julius
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Persyn, Janus Van.
# Matched author: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Wopkens, Thomas, 1700-1755.
# Matched author: {'authorized_name': 'wowern, johann van der, 1574-1612', 'author_id': 'A5942'}
# Processing: Curtius Rufus, Quintus
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Curtius Rufus, Quintus
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Frontinus, Sextus Julius
# Matched author: {'authorized_name': 'frontinus, sextus julius', 'author_id': 'A4597'}
# Processing: Gellius, Aulus
# Matched author: {'authorized_name': 'gellius, aulus', 'author_id': 'A5356'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Lachmann, Karl, 1793-1851
# Matched author: {'authorized_name': 'lachmann, karl, 1793-1851', 'author_id': 'A6090'}
# Processing: Mela, Pomponius
# Matched author: {'authorized_name': 'mela, pomponius', 'author_id': 'A4607'}
# Processing: Mela, Pomponius
# Matched author: {'authorized_name': 'mela, pomponius', 'author_id': 'A4607'}
# Processing: Nepos, Cornelius
# Matched author: {'authorized_name': 'nepos, cornelius', 'author_id': 'A5005'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Persius
# Matched author: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Rutilius Namatianus, Claudius, active 5th century
# Matched author: {'authorized_name': 'namatianus, claudius rutilius, active 5th century', 'author_id': 'A4453'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: {'authorized_name': 'seneca, lucius annaeus, approximately 4 b.c.-65 a.d.', 'author_id': 'A4655'}
# Processing: Silius Italicus, Tiberius Catius
# Matched author: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Processing: Statius, P. Papinius
# Matched author: {'authorized_name': 'statius, p. papinius (publius papinius)', 'author_id': 'A4826'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Valerius Maximus
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Vegetius Renatus, Publius
# Matched author: {'authorized_name': 'vegetius renatus, flavius', 'author_id': 'A4794'}
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Processing: Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# Matched author: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Braunhard, Wilhelm, 1807-1866.
# Matched author: {'authorized_name': 'brinkmann, august, 1863-1923', 'author_id': 'A3255'}
# Processing: Fuss, J. D, 1782-1860.
# Matched author: {'authorized_name': 'fux, johann joseph, 1660-1741', 'author_id': 'A4119'}
# Processing: Jordan, of Saxony, -1237
# Matched author: {'authorized_name': 'conradus, hirsaugiensis', 'author_id': 'A5076'}
# Processing: Monachus, Haymarus, Patriarch of Jerusalem, d. 1202.
# Matched author: {'authorized_name': 'jordan, of limoges', 'author_id': 'A5159'}
# Processing: Dietrich, Johann Friedrich, -1833.
# Matched author: {'authorized_name': 'dietrich, waldemar', 'author_id': 'A6198'}
# Processing: Abū Miḥjan al-Thaqafī, active 629-637
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Abū Miḥjan al-Thaqafī, active 629-637
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Muḥammad ibn 'Umar, al-Wākidī.
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Schmidt, Carl, 1868-1938
# Matched author: {'authorized_name': 'schmidt, paul wilhelm, 1845-1921', 'author_id': 'A5663'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Hauber, Karl Friedrich, 1775-1851.
# Matched author: {'authorized_name': 'dübner, fr. (friedrich), 1802-1867', 'author_id': 'A6094'}
# Processing: Linné, Carl von, 1707-1778
# Matched author: {'authorized_name': 'linné, carl von, 1707-1778', 'author_id': 'A5601'}
# Processing: Bianchi, Simon Giovanni, 1693-1775.
# Matched author: {'authorized_name': 'andreä, johann valentin, 1586-1654', 'author_id': 'A4229'}
# Processing: Dante Alighieri, 1265-1321
# Matched author: {'authorized_name': 'dante alighieri, 1265-1321', 'author_id': 'A4646'}
# Processing: Heine, Heinrich, 1797-1856
# Matched author: {'authorized_name': 'schmidt, wilhelm, 1862-1905', 'author_id': 'A6277'}
# Processing: Macer, Floridus.
# Matched author: {'authorized_name': 'odo magdunensis', 'author_id': 'A5031'}
# Processing: Zwingli, Ulrich 1484-1531.
# Matched author: {'authorized_name': 'zwingli, ulrich, 1484-1531', 'author_id': 'A5582'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Anselm, Saint, Archbishop of Canterbury, 1033-1109
# Matched author: {'authorized_name': 'anselm, saint, archbishop of canterbury', 'author_id': 'A5460'}
# Processing: Kazenberger, Kilian, -1750
# Matched author: {'authorized_name': 'hummelberger, gabriel, approximately 1490-1544', 'author_id': 'A5963'}
# Processing: Elvenich, Peter Joseph, 1796-1886
# Matched author: {'authorized_name': 'logus, georgius, 1484-1553', 'author_id': 'A5995'}
# Processing: Paulus, Julius.
# Matched author: {'authorized_name': 'paulus, julius', 'author_id': 'A3822'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Augustine, Saint, Bishop of Hippo
# Matched author: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Claudianus, Claudius
# Matched author: {'authorized_name': 'claudianus, claudius', 'author_id': 'A4503'}
# Processing: Claudianus, Claudius
# Matched author: {'authorized_name': 'claudianus, claudius', 'author_id': 'A4503'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Gellius, Aulus
# Matched author: {'authorized_name': 'gellius, aulus', 'author_id': 'A5356'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Mela, Pomponius
# Matched author: {'authorized_name': 'mela, pomponius', 'author_id': 'A4607'}
# Processing: Martial
# Matched author: {'authorized_name': 'martial', 'author_id': 'A5133'}
# Processing: Lucretius Carus, Titus
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Lucretius Carus, Titus
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: {'authorized_name': 'seneca, lucius annaeus, approximately 4 b.c.-65 a.d.', 'author_id': 'A4655'}
# Processing: Silius Italicus, Tiberius Catius
# Matched author: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Prudentius, 348-
# Matched author: {'authorized_name': 'prudentius, 348-', 'author_id': 'A4609'}
# Processing: Propertius, Sextus
# Matched author: {'authorized_name': 'propertius, sextus', 'author_id': 'A4889'}
# Processing: Quintilian.
# Matched author: {'authorized_name': 'quintilian', 'author_id': 'A5545'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Guarino, Veronese, 1374-1460
# Matched author: {'authorized_name': 'guarino, veronese, 1374-1460', 'author_id': 'A3982'}
# Processing: Apuleius.
# Matched author: {'authorized_name': 'apuleius', 'author_id': 'A5463'}
# Processing: Commodianus
# Matched author: {'authorized_name': 'commodianus', 'author_id': 'A5248'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Lucas, Christian Theodor Ludwig.
# Matched author: {'authorized_name': 'lucas, bishop of túy, -approximately 1249', 'author_id': 'A4371'}
# Processing: Herbert, of Bosham, fl. 1162-1186.
# Matched author: {'authorized_name': 'herbert, of bosham, active 12th century', 'author_id': 'A5106'}
# Processing: Luther, Martin, 1483-1546.
# Matched author: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Processing: Somoogyi, Ambrosius, fl. 1604.
# Matched author: {'authorized_name': 'oláh, miklós, 1493-1568', 'author_id': 'A4221'}
# Processing: Benedict XIV, Pope, 1675-1758
# Matched author: {'authorized_name': 'benedict i, pope', 'author_id': 'A5354'}
# Processing: Stosch, Ferdinand, 1717-1780.
# Matched author: {'authorized_name': 'meister, ferdinand otto, 1828-1915', 'author_id': 'A3273'}
# Processing: Borový, Klement, 1838-1897
# Matched author: {'authorized_name': 'borino, giovanni battista', 'author_id': 'A3292'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Duns Scotus, John, approximately 1266-1308
# Matched author: {'authorized_name': 'duns scotus, john, approximately 1266-1308', 'author_id': 'A5593'}
# Processing: Osorio, Jeronymo, Bishop of Silves, 1506-1580.
# Matched author: {'authorized_name': 'hosius, of córdoba', 'author_id': 'A5526'}
# Processing: Luther, Martin, 1483-1546.
# Matched author: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Długosz, Jan, 1415-1480
# Matched author: {'authorized_name': 'maciej, z miechowa, 1457?-1523', 'author_id': 'A3729'}
# Processing: Assemani, Giuseppe Luigi, 1710?-1782.
# Matched author: {'authorized_name': 'asser, john', 'author_id': 'A5500'}
# Processing: Forcellini, Egidio, 1688-1768
# Matched author: {'authorized_name': 'forcellini, egidio, 1688-1768', 'author_id': 'A3333'}
# Processing: Vigiliis von Creutzenfeld, Stephan Hieronymus de.
# Matched author: {'authorized_name': 'otto i, bishop of freising, -1158', 'author_id': 'A5033'}
# Processing: Kühnöl, Christian Gottlieb, 1768-1841,
# Matched author: {'authorized_name': 'harless, gottlieb christoph, 1738-1815', 'author_id': 'A6066'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Albategnius., d. 920.
# Matched author: {'authorized_name': 'arbonius silo', 'author_id': 'A3690'}
# Processing: Ḥamzah al-Iṣfahānī, 893 or 894-970 or 971.
# Matched author: {'authorized_name': 'anaritius, -approximately 922', 'author_id': 'A2491'}
# Processing: Tertullian, approximately 160-approximately 230
# Matched author: {'authorized_name': 'tertullian', 'author_id': 'A4829'}
# Processing: Pliny, the Elder
# Matched author: {'authorized_name': 'pliny, the elder', 'author_id': 'A5537'}
# Processing: Lucretius Carus, Titus
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Milton, John, 1608-1674.
# Matched author: {'authorized_name': 'milton, john', 'author_id': 'A4771'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Ordericus Vitalis, 1075-1143?
# Matched author: {'authorized_name': 'ordericus vitalis', 'author_id': 'A5529'}
# Processing: Viger, François, 1590-1647.
# Matched author: {'authorized_name': 'victor, vitensis', 'author_id': 'A4782'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Ambrose, Saint, Bishop of Milan, -397
# Matched author: {'authorized_name': 'ambrose, saint, bishop of milan', 'author_id': 'A5347'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Kepler, Johannes, 1571-1630.
# Matched author: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Processing: Lucan, 39-65
# Matched author: {'authorized_name': 'lucan', 'author_id': 'A5075'}
# Processing: Seneca, Lucius Annaeus, approximately 55 B.C.-approximately 39 A.D.
# Matched author: {'authorized_name': 'seneca, lucius annaeus, approximately 55 b.c.-approximately 39 a.d.', 'author_id': 'A4920'}
# Processing: Orzechowski, Stanisław Okszyc, 1513-1566 or 1567
# Matched author: {'authorized_name': 'miodoński, adam stefan, 1861-1913', 'author_id': 'A3469'}
# Processing: Juvenal.
# Matched author: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Processing: Zoega, Georg, 1755-1809
# Matched author: {'authorized_name': 'urba, karl franz', 'author_id': 'A5990'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Devarius, Matthaeus, b. 1505?
# Matched author: {'authorized_name': 'pacatus drepanius, latinus', 'author_id': 'A5089'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Persius
# Matched author: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Processing: Tibullus.
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Grotius, Hugo, 1583-1645
# Matched author: {'authorized_name': 'grotius, hugo, 1583-1645', 'author_id': 'A4206'}
# Processing: Catullus, Gaius Valerius.
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Abū al-Rabīʻ Sulaymān ibn ʻAbd Allāh al-Muwaḥḥid.
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Freytag, G. W.
# Matched author: {'authorized_name': 'frey, joseph, 1834-1910', 'author_id': 'A6205'}
# Processing: Suetonius, approximately 69-approximately 122
# Matched author: {'authorized_name': 'suetonius, approximately 69-approximately 122', 'author_id': 'A4799'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Abū Tammām Ḥabīb ibn Aws al-Ṭāʼī, active 808-842
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Zwingli, Ulrich 1484-1531.
# Matched author: {'authorized_name': 'zwingli, ulrich, 1484-1531', 'author_id': 'A5582'}
# Processing: Valerius Maximus
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Silius Italicus, Tiberius Catius
# Matched author: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Processing: Statius, P. Papinius
# Matched author: {'authorized_name': 'statius, p. papinius (publius papinius)', 'author_id': 'A4826'}
# Processing: Bonafous, Norbert Alexandre, b. 1809.
# Matched author: {'authorized_name': 'polignac, melchior de, 1661-1742?', 'author_id': 'A3852'}
# Processing: Hüpenden, Ludwig Philipp.
# Matched author: {'authorized_name': 'ludwig, ernst, 1845-1912', 'author_id': 'A3297'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Kimmel, Ernst Julius, 1812-1846.
# Matched author: {'authorized_name': 'peter, hermann, 1837-1914', 'author_id': 'A6260'}
# Processing: Locke, John, 1632-1704
# Matched author: {'authorized_name': 'phreas, john, -1465', 'author_id': 'A5624'}
# Processing: Tertullian, approximately 160-approximately 230
# Matched author: {'authorized_name': 'tertullian', 'author_id': 'A4829'}
# Processing: Valerius Maximus
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Nonius Marcellus, active 4th century
# Matched author: {'authorized_name': 'nonius marcellus', 'author_id': 'A4349'}
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: {'authorized_name': 'bacon, roger, 1214?-1294', 'author_id': 'A4387'}
# Processing: Suetonius, approximately 69-approximately 122
# Matched author: {'authorized_name': 'suetonius, approximately 69-approximately 122', 'author_id': 'A4799'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Muczkowski, Józef, 1795-1858
# Matched author: {'authorized_name': 'muczkowski, antoni, 1807-1852', 'author_id': 'A3319'}
# Processing: Avitus, Alcimus Ecdicius, Saint, d. 518.
# Matched author: {'authorized_name': 'avitus, saint, bishop of vienne', 'author_id': 'A5499'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Justinus, Marcus Junianus
# Matched author: {'authorized_name': 'justinus, marcus junianus', 'author_id': 'A5179'}
# Processing: Phaedrus
# Matched author: {'authorized_name': 'phaedrus', 'author_id': 'A4554'}
# Processing: David, von Augsburg, -1271
# Matched author: {'authorized_name': 'chytraeus, david, 1531-1600', 'author_id': 'A4036'}
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: {'authorized_name': 'muret, marc-antoine, 1526-1585', 'author_id': 'A3873'}
# Processing: Petrarca, Francesco, 1304-1374
# Matched author: {'authorized_name': 'petrarca, francesco', 'author_id': 'A4768'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Voltaire, 1694-1778
# Matched author: {'authorized_name': 'descartes, rené', 'author_id': 'A4762'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Keller, Friedrich Ludwig von, 1799-1860.
# Matched author: {'authorized_name': 'keller, otto, 1838-1927', 'author_id': 'A6232'}
# Processing: Balde, Jakob, 1604-1668
# Matched author: {'authorized_name': 'balde, jakob', 'author_id': 'A4703'}
# Processing: Balde, Jakob, 1604-1668
# Matched author: {'authorized_name': 'balde, jakob', 'author_id': 'A4703'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Bothe, Friedrich Heinrich, 1771-1855.
# Matched author: {'authorized_name': 'lindenbrog, heinrich, 1570-1642', 'author_id': 'A6016'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Duns Scotus, John, approximately 1266-1308
# Matched author: {'authorized_name': 'duns scotus, john, approximately 1266-1308', 'author_id': 'A5593'}
# Processing: Blois, Louis de, 1506-1566.
# Matched author: {'authorized_name': 'henry, of blois, bishop of winchester, approximately 1090-1171', 'author_id': 'A3913'}
# Processing: Clement, Joannes Franciscus, 1823-1892.
# Matched author: {'authorized_name': 'jan, ludwig von 1807-1869', 'author_id': 'A3483'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Pliny, the Younger
# Matched author: {'authorized_name': 'pliny, the younger', 'author_id': 'A4904'}
# Processing: Tacitus, Cornelius
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Pliny, the Elder
# Matched author: {'authorized_name': 'pliny, the elder', 'author_id': 'A5537'}
# Processing: Pliny, the Younger
# Matched author: {'authorized_name': 'pliny, the younger', 'author_id': 'A4904'}
# Processing: Spohn, Friedrich August Wilhelm, 1792-1824
# Matched author: {'authorized_name': 'krohn, fritz, 1873-1941', 'author_id': 'A6144'}
# Processing: Viger, François, 1590-1647
# Matched author: {'authorized_name': 'victor, vitensis', 'author_id': 'A4782'}
# Processing: Cicero, Marcus Tullius
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Valerius Maximus,
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Caesar, Julius
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Frontinus, Sextus Julius.
# Matched author: {'authorized_name': 'frontinus, sextus julius', 'author_id': 'A4597'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Madvig, J. N. 1804-1886
# Matched author: {'authorized_name': 'madvig, j. n. (johan nikolai), 1804-1886', 'author_id': 'A3149'}
# Processing: Blois, Louis de, 1506-1566
# Matched author: {'authorized_name': 'henry, of blois, bishop of winchester, approximately 1090-1171', 'author_id': 'A3913'}
# Processing: Ghiringhello, Giuseppe.
# Matched author: {'authorized_name': 'landulf, of milan', 'author_id': 'A5053'}
# Processing: Vlis, Christian Jacob van der.
# Matched author: {'authorized_name': 'vliet, joannes van der, 1847-1902', 'author_id': 'A6128'}
# Processing: Vitruvius Pollio
# Matched author: {'authorized_name': 'vitruvius pollio', 'author_id': 'A4853'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Capaccio, Giulio Cesare, 1552-1634
# Matched author: {'authorized_name': 'braccesi, alessandro, 1445-1503', 'author_id': 'A4078'}
# Processing: Thiele, Georg, 1866-1917.
# Matched author: {'authorized_name': 'müller, moritz, 1854-', 'author_id': 'A3418'}
# Processing: Tibullus
# Matched author: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Processing: Victor, Sextus Aurelius
# Matched author: {'authorized_name': 'victor, sextus aurelius', 'author_id': 'A4936'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Pliny, the Younger.
# Matched author: {'authorized_name': 'pliny, the younger', 'author_id': 'A4904'}
# Processing: Valerius Flaccus, Gaius, active 1st century
# Matched author: {'authorized_name': 'valerius flaccus, gaius', 'author_id': 'A4806'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Horace
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Jacob, J. F.
# Matched author: {'authorized_name': 'jacob, émile, 1867-1953', 'author_id': 'A3321'}
# Processing: Cyprian, Saint, Bishop of Carthage
# Matched author: {'authorized_name': 'cyprian, saint, bishop of carthage', 'author_id': 'A5298'}
# Processing: Livy
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Valerius Maximus
# Matched author: {'authorized_name': 'valerius maximus', 'author_id': 'A4545'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Catullus, Gaius Valerius.
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Kimchi, David, 1160?-1235.
# Matched author: {'authorized_name': 'mattias, -1350', 'author_id': 'A4351'}
# Processing: Quintilian
# Matched author: {'authorized_name': 'quintilian', 'author_id': 'A5545'}
# Processing: Petrarca, Francesco, 1304-1374
# Matched author: {'authorized_name': 'petrarca, francesco', 'author_id': 'A4768'}
# Processing: Agassiz, Louis, 1807-1873.
# Matched author: {'authorized_name': 'grégoire, l. (louis), 1819-1897', 'author_id': 'A3154'}
# ...
# Processing: Nithard, -844?
# Matched author: {'authorized_name': 'nithard, -844?', 'author_id': 'A5028'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Wesseling, Petrus, 1692-1764.
# Matched author: {'authorized_name': 'wessely, carl, 1860-1931', 'author_id': 'A3348'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Sedulius, 5th cent.
# Matched author: {'authorized_name': 'sedulius, active 5th century', 'author_id': 'A5260'}
# Processing: Vossius, Gerardus Joannes, 1577-1649.
# Matched author: {'authorized_name': 'vossius, gerardus joannes, 1577-1649', 'author_id': 'A3771'}
# Processing: Amarcius, active 11th century
# Matched author: {'authorized_name': 'amarcius', 'author_id': 'A5440'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Catullus, Gaius Valerius.
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Catullus, Gaius Valerius
# Matched author: {'authorized_name': 'catullus, gaius valerius', 'author_id': 'A5237'}
# Processing: Sallust, 86-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Virgil
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Ibn ʻArabshāh, Aḥmad ibn Muḥammad, 1392-1450
# Matched author: {'authorized_name': 'avicenna, 980-1037', 'author_id': 'A5701'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Hagen, Hermann, 1844-1898,
# Matched author: {'authorized_name': 'hagen, hermann, 1844-1898', 'author_id': 'A6213'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Hilary, Saint, Bishop of Poitiers, d. 367?
# Matched author: {'authorized_name': 'hilary, saint, bishop of poitiers, -367?', 'author_id': 'A5124'}
# Processing: Augustine, Saint, Bishop of Hippo.
# Matched author: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Processing: Pliny, the Younger.
# Matched author: {'authorized_name': 'pliny, the younger', 'author_id': 'A4904'}
# Processing: Pliny, the Elder.
# Matched author: {'authorized_name': 'pliny, the elder', 'author_id': 'A5537'}
# Processing: Valerius Flaccus, Gaius, 1st cent.
# Matched author: {'authorized_name': 'valerius flaccus, gaius', 'author_id': 'A4806'}
# Processing: Valerius Flaccus, Gaius, 1st cent.
# Matched author: {'authorized_name': 'valerius flaccus, gaius', 'author_id': 'A4806'}
# Processing: Viger, François, 1590-1647.
# Matched author: {'authorized_name': 'victor, vitensis', 'author_id': 'A4782'}
# Processing: Sallust, 86-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Lucan, 39-65.
# Matched author: {'authorized_name': 'lucan', 'author_id': 'A5075'}
# Processing: Caesar, Julius.
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Caesar, Julius.
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Curtius Rufus, Quintus.
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Haymarus Monachus, d. 1202.
# Matched author: {'authorized_name': 'haimo, of auxerre, -approximately 855', 'author_id': 'A4495'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Caesar, Julius.
# Matched author: {'authorized_name': 'caesar, julius', 'author_id': 'A4644'}
# Processing: Henricus, de Hervordia, d. 1370.
# Matched author: {'authorized_name': 'henry iii, king of france, 1551-1589', 'author_id': 'A6010'}
# Processing: Propertius, Sextus.
# Matched author: {'authorized_name': 'propertius, sextus', 'author_id': 'A4889'}
# Processing: Janus, Secundus, 1511-1536.
# Matched author: {'authorized_name': 'janus, secundus', 'author_id': 'A4717'}
# Processing: Statius, P. Papinius
# Matched author: {'authorized_name': 'statius, p. papinius (publius papinius)', 'author_id': 'A4826'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: {'authorized_name': 'bacon, roger, 1214?-1294', 'author_id': 'A4387'}
# Processing: Abū Miḥjan al-Thaqafī, fl. 629-637.
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Curtius Rufus, Quintus.
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Olivet, Pierre-Joseph Thoulier, abbé d', 1682-1768.
# Matched author: {'authorized_name': 'fleury, julien, 1647-1725', 'author_id': 'A5946'}
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Sallust, 86-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Dymmok, Roger, fl. 1395.
# Matched author: {'authorized_name': 'thomas monumetensis ca. 1170', 'author_id': 'A3077'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Virgil.
# Matched author: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Processing: Quintilian.
# Matched author: {'authorized_name': 'quintilian', 'author_id': 'A5545'}
# Processing: Thomas, de Cantimpré, ca. 1200-ca. 1270.
# Matched author: {'authorized_name': 'thomas of celano 1190-1260', 'author_id': 'A3076'}
# Processing: Thomas, of Ely, fl. 1174.
# Matched author: {'authorized_name': 'thomas of celano 1190-1260', 'author_id': 'A3076'}
# Processing: Graetz, Heinrich, 1817-1891.
# Matched author: {'authorized_name': 'graevius, joannes georgius, 1632-1703', 'author_id': 'A6032'}
# Processing: Storr, Rayner.
# Matched author: {'authorized_name': 'stretzinger, thomas, -1523', 'author_id': 'A4179'}
# Processing: Hoffmann, Emanuel, 1825-1900.
# Matched author: {'authorized_name': 'hoffmann, christian gottfried, 1692-1735', 'author_id': 'A3377'}
# Processing: Petronius Arbiter.
# Matched author: {'authorized_name': 'petronius arbiter', 'author_id': 'A4886'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Dubrovnik (Republic)
# Matched author: {'authorized_name': 'columbus, christopher', 'author_id': 'A4744'}
# Processing: Schuster, Ildefonso, 1880-1954.
# Matched author: {'authorized_name': 'ildephonsus, saint', 'author_id': 'A5513'}
# Processing: Dietrich, von Nieheim, ca. 1340-1418.
# Matched author: {'authorized_name': 'loër, dirk, approximately 1495-1554', 'author_id': 'A4174'}
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: {'authorized_name': 'gonzález téllez, manuel, -1649', 'author_id': 'A3366'}
# Processing: Vries, Hugo de, 1848-1935.
# Matched author: {'authorized_name': 'laemmer, hugo, 1835-1918', 'author_id': 'A5960'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Curtius Rufus, Quintus.
# Matched author: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Processing: Cicero, Marcus Tullius.
# Matched author: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Processing: Vinkesteyn, Cornelius Joannes.
# Matched author: {'authorized_name': 'jansenius, cornelius, 1510-1576', 'author_id': 'A4213'}
# Processing: Wycliffe, John, d. 1384.
# Matched author: {'authorized_name': 'wycliffe, john, -1384', 'author_id': 'A4338'}
# Processing: Buchanan, David, 1595?-1652?
# Matched author: {'authorized_name': 'buchanan, george', 'author_id': 'A4730'}
# Processing: Munkelif, Norway. (Benedictine Monastery)
# Matched author: {'authorized_name': 'notger, bishop of liège', 'author_id': 'A5525'}
# Processing: Priscianus, Theodorus.
# Matched author: {'authorized_name': 'priscianus, theodorus', 'author_id': 'A3493'}
# Processing: Heydenreich, Wilhelm, 1875-
# Matched author: {'authorized_name': 'hildebrand, gustav friedrich, 1812-1869', 'author_id': 'A5970'}
# Processing: Sallust, 86-34 B.C.
# Matched author: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Brink, Barend ten, 1803-1875.
# Matched author: {'authorized_name': 'brinkmann, august, 1863-1923', 'author_id': 'A3255'}
# Processing: Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# Matched author: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Campion, Thomas, 1567-1620.
# Matched author: {'authorized_name': 'campion, thomas', 'author_id': 'A5559'}
# Processing: Moritz, C.
# Matched author: {'authorized_name': 'müller, moritz, 1816-1895', 'author_id': 'A3239'}
# Processing: Palingenio Stellato, Marcello, ca. 1500-ca. 1543.
# Matched author: {'authorized_name': 'palingenio stellato, marcello, approximately 1500-approximately 1543', 'author_id': 'A3887'}
# Processing: Milchsack, Gustav, 1850-1919.
# Matched author: {'authorized_name': 'seeck, otto, 1850-1921', 'author_id': 'A6131'}
# Processing: Juvenal.
# Matched author: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Horace.
# Matched author: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Processing: Juvenal.
# Matched author: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Lucretius Carus, Titus.
# Matched author: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Processing: Manilius, Marcus.
# Matched author: {'authorized_name': 'manilius, marcus', 'author_id': 'A5565'}
# Processing: Rutilius Lupus, Publius.
# Matched author: {'authorized_name': 'rutilius lupus, publius', 'author_id': 'A4568'}
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Processing: Persius.
# Matched author: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Livy.
# Matched author: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Processing: Lucan, 39-65.
# Matched author: {'authorized_name': 'lucan', 'author_id': 'A5075'}
# Processing: Petermann, August, 1818-
# Matched author: {'authorized_name': 'peter, hermann, 1837-1914', 'author_id': 'A6260'}
# Processing: Tacitus, Cornelius.
# Matched author: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Processing: Portus, Aemilius, 1550-1614 or 15.
# Matched author: {'authorized_name': 'alanus, de insulis', 'author_id': 'A4458'}
# Processing: Linné, Carl von, 1707-1778
# Matched author: {'authorized_name': 'linné, carl von, 1707-1778', 'author_id': 'A5601'}
# Processing: Petau, Denis, 1583-1652.
# Matched author: {'authorized_name': 'philippe de prétot, étienne-andré, 1710-1787', 'author_id': 'A6056'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Knabenbauer, Joseph, 1839-1911.
# Matched author: {'authorized_name': 'krahner, leopold, 1810-1884', 'author_id': 'A6102'}
# Processing: Thomas, à Kempis, 1380-1471.
# Matched author: {'authorized_name': 'thomas, à kempis, 1380-1471', 'author_id': 'A4319'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Processing: Persius.
# Matched author: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Processing: Jaʻfarī, Ṣāliḥ ibn al-Ḥusayn, d. 1269 or 70., جعفري، صالح بن الحسين.
# Matched author: {'authorized_name': 'rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?', 'author_id': 'A5671'}
# Processing: Unknown
# Matched author: {'authorized_name': 'alan, of tewkesbury', 'author_id': 'A4551'}
# Done with processing authors.

# %% [markdown]
# ### End the Timer and the EmissionsTracker for Author Reconciliation

# %%
# End the timer
end_time = time.time()
print(f"Execution time: {end_time - start_time:.2f} seconds")
# Stop the emissions tracker after training is complete
emissions = tracker.stop()
print(f"Estimated CO2 emissions for author reconciliation: {emissions} kg")
# Out:
# [codecarbon INFO @ 14:49:43] Energy consumed for RAM : 0.000330 kWh. RAM Power : 9.000000000000002 W
# [codecarbon INFO @ 14:49:43] Energy consumed for all CPUs : 0.001559 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:49:43] 0.001890 kWh of electricity used since the beginning.
# Execution time: 132.09 seconds
# Estimated CO2 emissions for author reconciliation: 0.0008945987056582037 kg

# %% [markdown]
# ### Display the First Ten Rows of the Output

# %%
display(output_df.head(10))
# Out:
#                                               author  \
# 0                    Du Creux, François, 1596?-1666.
# 1                      Meyer, Ernst H. F. 1791-1858.
# 2                       Laet, Joannes de, 1593-1649.
# 3                                     Caesar, Julius
# 4                                            Unknown
# 5                       Drexel, Jeremias, 1581-1638,
# 6                     Kircher, Athanasius, 1602-1680
# 7  Hincmar, Archbishop of Reims, approximately 80...
# 8                       Acosta, José de, 1540-1600,
# 9                      Lessius, Leonardus, 1554-1623
#
#                                   normalized_author  \
# 0                        du creux francois 15961666
# 1                          meyer ernst h f 17911858
# 2                          laet joannes de 15931649
# 3                                     caesar julius
# 4                                           unknown
# 5                          drexel jeremias 15811638
# 6                       kircher athanasius 16021680
# 7  hincmar archbishop of reims approximately 806882
# 8                           acosta jose de 15401600
# 9                        lessius leonardus 15541623
#
#                                    distilbert_author  confidence
# 0  {'authorized_name': 'graux, charles henri, 185...    0.177464
# 1  {'authorized_name': 'meyer, wilhelm, 1845-1917...    0.999956
# 2  {'authorized_name': 'lawrence, of novara', 'au...    0.156866
# 3  {'authorized_name': 'caesar, julius', 'author_...    0.999986
# 4  {'authorized_name': 'alan, of tewkesbury', 'au...    0.110270
# 5  {'authorized_name': 'dorpius, martinus, 1485-1...    0.521497
# 6  {'authorized_name': 'kircher, athanasius, 1602...    0.999991
# 7  {'authorized_name': 'hincmar, archbishop of re...    0.999999
# 8  {'authorized_name': 'acosta, josé de, 1540-16...    0.999997
# 9  {'authorized_name': 'lessing, gotthold ephraim...    0.985865

# %% [markdown]
# ### Write the results to a CSV

# %%
output_df.to_csv('../output/author_inferences.csv',index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)

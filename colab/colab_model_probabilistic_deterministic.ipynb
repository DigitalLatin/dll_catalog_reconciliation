# %% [markdown]
# # Comparing the Models to Other Matching Algorithms
#
# This notebook compares the output of the author matching pipeline to deterministic and probabilistic matching algorithms.
#
# It reads in the records that were identified as "Latin" by the Greek-Latin Identification model. It normalizes the value of the "author" column and seeks to match it to the authorized name form in the DLL Catalog. It tries three methods for matching: deterministic, probabilistic (fuzzy), and inference-based (using the inferences of the Author Identification model).
#
# The input data is very noisy, with multiple name forms for the same author and multiple rows for some authors (see below "Analysis").
#
# To run this notebook, you also need the following files:
#
# - data/authors_db.csv
# - data/works_db.csv
# - output/author_inferences.csv
# - output/latin_authors.csv

# %%
# %pip install rapidfuzz

# %% [markdown]
# ## Load the Necessary Modules
#
# This notebook uses the following modules:
#
# - `ast`: (Abstract Syntax Tree) to handle processing some items as a string
# - `csv`: for processing the output of the model
# - `pandas`: for opening and working with the CSV files
# - `rapidfuzz`: for comparing the models' inferences to deterministic and probabilistic matching algorithms
# - `utilities`: for some local helper functions. Note: this is a local file, not a library available through repos like condaforge or pypl.

# %%
import ast
import csv
import pandas as pd
from rapidfuzz import fuzz, process
import utilities as utilities

# %% [markdown]
# ## Load the Data

# %% [markdown]
# ### Load the DLL Catalog Data
#
# The authority and work records from the DLL Catalog are loaded from CSV files and converted into Python dictionaries. These will be used as lookup tables to translate the outputs from the Author Reconciliation model into more comprehensible information for humans (e.g., "Julius Caesar", not "A4644").

# %%
# Read in the authors data
authors = pd.read_csv('./authors_db.csv',encoding='utf-8',quotechar='"')
# Read in the works data
works = pd.read_csv('./works_db.csv',encoding='utf-8',quotechar='"')

# Change the names of the columns to be lower case without spaces or punctuation
authors = authors.rename(columns={'Variant':'variant_name','Authorized Name':'authorized_name','DLL Identifier (Author)':'dll_id_author'})
works = works.rename(columns={'Title':'title','DLL Identifier (Work)':'dll_id_work','DLL Identifier (Author)': 'dll_id_author'})

# Prepare the lookup dictionaries of variant author names and titles
variant_to_authorized, title_to_work = utilities.prepare_dicts(authors,works)

# %% [markdown]
# ### Load the Model Inference Data
#
# Load the output of the `author_matching.ipynb` notebook instead of running the models again.

# %%
model_outputs_df = pd.read_csv("./author_inferences.csv",encoding='utf-8',quotechar='"')

# %% [markdown]
# ### Load the Latin Data from the Original Test Data

# %%
# Load preprocessed, deduplicated hathi2.csv
input_df = pd.read_csv('./latin_authors.csv', encoding='utf-8', quotechar='"') 
# Further clean the data by filling missing values with "Unknown"
input_df = utilities.clean_input(input_df)

# %% [markdown]
# ## Metadata Processing Functions
#
# The following functions are necessary for providing comprehensible output from the models' inferences.
#
# ### Greek-Latin Identification
#
# - `classify_author_language`: Tokenizes authors' names from the incoming metadata records and passes them to the Greek-Latin Identification model. Returns the predicted label ("Greek" or "Latin") and the confidence score for the prediction.
# - `classify_and_split_by_language`: Returns three Pandas dataframes—`classified_df`, with all results from the Greek-Latin Identification model; `greek_df`, with results labeled "Greek"; `latin_df`, with results labeled "Latin". The latter will be the input for the Author Reconciliation model.
#
# Note that these functions process one input at a time. There is potential for speeding up the process by batching the inputs.

# %% [markdown]
# ### Author Reconciliation Functions
#
# - `deterministic_author_match`: Performs a one-to-one comparison of the authorized name in the DLL Catalog with the value of the author field in the test data
# - `fuzzy_author_match`: Performs a "fuzzy" comparison and selects the best match between names in the DLL Catalog and the value of the author field, provided the confidence is above 90%.
# - `distilbert_author_match`: Tokenizes authors' names and passes them to the Author Reconciliation model. Returns the predicted label ("DLL ID") and the confidence score for the prediction.
# - `process_metadata`: Manages input and output for the Author Reconciliation model. Returns a dataframe with the results of the inference run.
#
# Note that these functions process one input at a time. There is potential for speeding up the process by batching the inputs.

# %%
# Step 2: Author Matching Functions
def deterministic_author_match(input_author):
    input_author_normalized = utilities.normalize_author_name(input_author)
    author_info = variant_to_authorized.get(input_author_normalized)
    return author_info

def fuzzy_author_match(input_author):
    input_author_cleaned = utilities.normalize_author_name(input_author)
    result = process.extractOne(input_author_cleaned, list(variant_to_authorized.keys()), scorer=fuzz.token_sort_ratio)
    if result:
        best_match, similarity, *_ = result
        if similarity == 1.0:
            return variant_to_authorized.get(best_match), similarity / 100
    return None, 0.0

def distilbert_author_match(input_author):
    if not isinstance(input_author, str):
        return None, 0.0

    row = model_outputs_df[model_outputs_df['author'] == input_author]
    if row.empty:
        return None, 0.0

    # Parse the dictionary string in 'distilbert_author'
    distilbert_author = ast.literal_eval(row.iloc[0]['distilbert_author'])
    authorized_name = distilbert_author.get('authorized_name', None)
    confidence = float(row.iloc[0]['confidence'])

    return authorized_name, confidence

def process_metadata(input_df):
    """Process input dataframe and match metadata, returning only authorized_name values."""
    results = []

    for _, row in input_df.iterrows():
        input_author_original = row["author"]
        input_author_normalized = utilities.normalize_author_name(input_author_original)
        print(f'Processing: {input_author_original}')

        # Author Matching
        deterministic_author = deterministic_author_match(input_author_normalized)
        fuzzy_author, fuzzy_author_score = fuzzy_author_match(input_author_normalized)
        distilbert_author, distilbert_author_score = distilbert_author_match(input_author_original)

        # Extract just the authorized_name if available
        deterministic_author_name = (
            deterministic_author.get("authorized_name") if deterministic_author else None
        )
        fuzzy_author_name = (
            fuzzy_author.get("authorized_name") if fuzzy_author else None
        )

        # Collect Results
        results.append({
            "author": input_author_original,
            "normalized_author": input_author_normalized,
            "deterministic_author": deterministic_author_name,
            "fuzzy_author": fuzzy_author_name,
            "fuzzy_author_score": fuzzy_author_score,
            "distilbert_author": distilbert_author,
            "distilbert_author_score": distilbert_author_score
        })
        print(f"Matched author: {deterministic_author_name if deterministic_author_name else distilbert_author}")

    return pd.DataFrame(results)

# %% [markdown]
# ## Process the Data

# %%
# Process the input dataframe
output_df = process_metadata(input_df)
# Display a message indicating completion
print("Done with processing authors and titles.")
# Display the first 10 rows of the output dataframe
display(output_df.head(10))
# Save the output dataframe to a CSV file
output_df.to_csv('./model_probabilistic_deterministic.csv',index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
# Out:
# Processing: Du Creux, François, 1596?-1666.
# Matched author: graux, charles henri, 1852-1882
# Processing: Meyer, Ernst H. F. 1791-1858.
# Matched author: meyer, wilhelm, 1845-1917
# Processing: Laet, Joannes de, 1593-1649.
# Matched author: lawrence, of novara
# Processing: Caesar, Julius
# Matched author: caesar, julius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Drexel, Jeremias, 1581-1638,
# Matched author: dorpius, martinus, 1485-1525
# Processing: Kircher, Athanasius, 1602-1680
# Matched author: kircher, athanasius, 1602-1680
# Processing: Hincmar, Archbishop of Reims, approximately 806-882
# Matched author: hincmar, archbishop of reims
# Processing: Acosta, José de, 1540-1600,
# Matched author: acosta, josé de, 1540-1600
# Processing: Lessius, Leonardus, 1554-1623
# Matched author: lessing, gotthold ephraim, 1729-1781
# Processing: Riccioli, Giovanni Battista, 1598-1671,
# Matched author: ricci, matteo, 1552-1610
# Processing: Guazzo, Francesco Maria,
# Matched author: giovio, benedetto, 1471-1545
# Processing: Kircher, Athanasius, 1602-1680.
# Matched author: kircher, athanasius, 1602-1680
# Processing: Mersenne, Marin, 1588-1648,
# Matched author: mersenne, marin, 1588-1648
# Processing: Virgil.
# Matched author: virgil
# Processing: Kepler, Johannes, 1571-1630.
# Matched author: kepler, johannes
# Processing: Roothaan, Joannes Philippus, 1785-1853
# Matched author: heidenhain, friedrich jakob, 1845-1912
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Alvares, Manuel, 1526-1583.
# Matched author: alvares, manuel, 1526-1583
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Huygens, Constantijn, 1596-1687
# Matched author: huygens, christiaan, 1629-1695
# Processing: Nieremberg, Juan Eusebio, 1595-1658.
# Matched author: schweickhofer, johannes
# Processing: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621.
# Matched author: longolius, christophorus, 1488-1522
# Processing: Reiske, Johann Jacob, 1716-1774.
# Matched author: reisch, emil, 1863-1933
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Virgil.
# Matched author: virgil
# Processing: Boethius, -524.
# Matched author: boethius, -524
# Processing: Prosper, of Aquitaine, Saint, approximately 390-approximately 463.
# Matched author: prosper, of aquitaine, saint
# Processing: Vitruvius Pollio.
# Matched author: vitruvius pollio
# Processing: Thomas, Aquinas, Saint, 1225?-1274.
# Matched author: thomas, aquinas, saint
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Torsellino, Orazio, 1545-1599.
# Matched author: horatius romanus
# Processing: Juvencus, Caius Vettius Aquilinus.
# Matched author: juvencus, caius vettius aquilinus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Hyginus, Gromaticus.
# Matched author: hyginus, gromaticus
# Processing: Horace
# Matched author: horace
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Rostowski, Stanislaw, 1711-1784.
# Matched author: morawski, kazimierz, 1852-1925
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: valerius flaccus, gaius
# Processing: Livy.
# Matched author: livy
# Processing: Duns Scotus, John, ca. 1266-1308.
# Matched author: duns scotus, john, approximately 1266-1308
# Processing: Navarrete, Jean André, 1730-1811.
# Matched author: galilei, galileo
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Commodianus.
# Matched author: commodianus
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Suarez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Copernicus, Nicolaus, 1473-1543
# Matched author: copernicus, nicolaus, 1473-1543
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Nonius Marcellus, active 4th century.
# Matched author: nonius marcellus
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: bacon, roger, 1214?-1294
# Processing: Nakatenus, Wilhelm, 1617-1682.
# Matched author: institoris, heinrich, 1430-1505
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Gretser, Jakob, 1562-1625.
# Matched author: gretser, jakob, 1562-1625
# Processing: Palladius, Rutilius Taurus Aemilianus.
# Matched author: palladius, rutilius taurus aemilianus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Huygens, Christiaan, 1629-1695.
# Matched author: huygens, christiaan, 1629-1695
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Valerius Maximus.
# Matched author: valerius maximus
# Processing: Livy.
# Matched author: livy
# Processing: Silius Italicus, Tiberius Catius.
# Matched author: silius italicus, tiberius catius
# Processing: Victor, Sextus Aurelius.
# Matched author: victor, sextus aurelius
# Processing: Callaghan, John, 1605-1654,
# Matched author: lynch, john, approximately 1599-approximately 1673
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Kircher, Athanasius, 1602-1680
# Matched author: kircher, athanasius, 1602-1680
# Processing: Claudianus, Claudius
# Matched author: claudianus, claudius
# Processing: Knabenbauer, Joseph, 1839-1911.
# Matched author: krahner, leopold, 1810-1884
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Florus, Lucius Annaeus.
# Matched author: florus, lucius annaeus
# Processing: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621.
# Matched author: longolius, christophorus, 1488-1522
# Processing: Suarez, Francisco, 1548-1617,
# Matched author: suárez, francisco, 1548-1617
# Processing: Propertius, Sextus.
# Matched author: propertius, sextus
# Processing: Noceti, Carlo, 1694-1759.
# Matched author: nobili, roberto de' 1577-1656
# Processing: Maffei, Giovanni Pietro, 1536?-1603.
# Matched author: maffei, giovanni pietro, 1536?-1603
# Processing: Thomas, Aquinas, Saint, 1225?-1274.
# Matched author: thomas, aquinas, saint
# Processing: Franchis, Francesco de.
# Matched author: negri, francesco, 1452-approximately 1523
# Processing: Pliny, the Elder
# Matched author: pliny, the elder
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Horatius, Romanus, fl. 1450.
# Matched author: horatius romanus
# Processing: Doni, Gio. Battista 1593 or 1594-1647
# Matched author: donizone, di canossa
# Processing: Viger, François, 1590-1647
# Matched author: victor, vitensis
# Processing: Lucas, Karl Wilhelm.
# Matched author: lucas, bishop of túy, -approximately 1249
# Processing: Portus, Aemilius, 1550-1614 or 1615
# Matched author: alanus, de insulis
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: muret, marc-antoine, 1526-1585
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: muret, marc-antoine, 1526-1585
# Processing: Klausen, Rudolf Heinrich, 1807-1840.
# Matched author: schöll, rudolf, 1844-1893
# Processing: Martin, Bernard, 1574-1639.
# Matched author: andreas, bernard, active 1500
# Processing: Wesseling, Petrus, 1692-1764
# Matched author: wessely, carl, 1860-1931
# Processing: Hanow, Rudolf, 1806-1871.
# Matched author: schottennius, hermannus
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Curtius Rufus, Quintus
# Matched author: curtius rufus, quintus
# Processing: Florus, Lucius Annaeus
# Matched author: florus, lucius annaeus
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Burchard, Johann Friedrich Wilhelm,
# Matched author: burchard, von reichenau
# Processing: Vater, Johann Severin, 1771-1826
# Matched author: pufendorf, samuel, freiherr von, 1632-1694
# Processing: Henrichsen, Rudolf Johann Frederik, 1800-1871.
# Matched author: schmidt, wilhelm, 1862-1905
# Processing: Lauer, Julius Franz, 1819-1850.
# Matched author: frey, joseph, 1834-1910
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Groke, Th. Wilhelm.
# Matched author: gemoll, wilhelm, 1850-1934
# Processing: Butler, Samuel, 1774-1839
# Matched author: cowley, abraham, 1618-1667
# Processing: Katrares, Johannes, 14th cent.
# Matched author: john, canonicus, active 14th century
# Processing: Augustine, of Hippo, Saint, 354-430.
# Matched author: augustine, of hippo, saint, 354-430
# Processing: Caesar, Julius
# Matched author: caesar, julius
# Processing: Caesar, Julius
# Matched author: caesar, julius
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Persyn, Janus Van.
# Matched author: persius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Wopkens, Thomas, 1700-1755.
# Matched author: wowern, johann van der, 1574-1612
# Processing: Curtius Rufus, Quintus
# Matched author: curtius rufus, quintus
# Processing: Curtius Rufus, Quintus
# Matched author: curtius rufus, quintus
# Processing: Frontinus, Sextus Julius
# Matched author: frontinus, sextus julius
# Processing: Gellius, Aulus
# Matched author: gellius, aulus
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Lachmann, Karl, 1793-1851
# Matched author: lachmann, karl, 1793-1851
# Processing: Mela, Pomponius
# Matched author: mela, pomponius
# Processing: Mela, Pomponius
# Matched author: mela, pomponius
# Processing: Nepos, Cornelius
# Matched author: nepos, cornelius
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Persius
# Matched author: persius
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Rutilius Namatianus, Claudius, active 5th century
# Matched author: namatianus, claudius rutilius, active 5th century
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: seneca, lucius annaeus, approximately 4 b.c.-65 a.d.
# Processing: Silius Italicus, Tiberius Catius
# Matched author: silius italicus, tiberius catius
# Processing: Statius, P. Papinius
# Matched author: statius, p. papinius (publius papinius)
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tibullus
# Matched author: tibullus
# Processing: Tibullus
# Matched author: tibullus
# Processing: Tibullus
# Matched author: tibullus
# Processing: Tibullus
# Matched author: tibullus
# Processing: Valerius Maximus
# Matched author: valerius maximus
# Processing: Vegetius Renatus, Publius
# Matched author: vegetius renatus, flavius
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: velleius paterculus
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: velleius paterculus
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: velleius paterculus
# Processing: Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# Matched author: velleius paterculus
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil
# Matched author: virgil
# Processing: Braunhard, Wilhelm, 1807-1866.
# Matched author: brinkmann, august, 1863-1923
# Processing: Fuss, J. D, 1782-1860.
# Matched author: fux, johann joseph, 1660-1741
# Processing: Jordan, of Saxony, -1237
# Matched author: conradus, hirsaugiensis
# Processing: Monachus, Haymarus, Patriarch of Jerusalem, d. 1202.
# Matched author: jordan, of limoges
# Processing: Dietrich, Johann Friedrich, -1833.
# Matched author: dietrich, waldemar
# Processing: Abū Miḥjan al-Thaqafī, active 629-637
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Abū Miḥjan al-Thaqafī, active 629-637
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Muḥammad ibn 'Umar, al-Wākidī.
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Schmidt, Carl, 1868-1938
# Matched author: schmidt, paul wilhelm, 1845-1921
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Hauber, Karl Friedrich, 1775-1851.
# Matched author: dübner, fr. (friedrich), 1802-1867
# Processing: Linné, Carl von, 1707-1778
# Matched author: linné, carl von, 1707-1778
# Processing: Bianchi, Simon Giovanni, 1693-1775.
# Matched author: andreä, johann valentin, 1586-1654
# Processing: Dante Alighieri, 1265-1321
# Matched author: dante alighieri, 1265-1321
# Processing: Heine, Heinrich, 1797-1856
# Matched author: schmidt, wilhelm, 1862-1905
# Processing: Macer, Floridus.
# Matched author: odo magdunensis
# Processing: Zwingli, Ulrich 1484-1531.
# Matched author: zwingli, ulrich, 1484-1531
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Anselm, Saint, Archbishop of Canterbury, 1033-1109
# Matched author: anselm, saint, archbishop of canterbury
# Processing: Kazenberger, Kilian, -1750
# Matched author: hummelberger, gabriel, approximately 1490-1544
# Processing: Elvenich, Peter Joseph, 1796-1886
# Matched author: logus, georgius, 1484-1553
# Processing: Paulus, Julius.
# Matched author: paulus, julius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Augustine, Saint, Bishop of Hippo
# Matched author: augustine, of hippo, saint, 354-430
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Claudianus, Claudius
# Matched author: claudianus, claudius
# Processing: Claudianus, Claudius
# Matched author: claudianus, claudius
# Processing: Horace
# Matched author: horace
# Processing: Gellius, Aulus
# Matched author: gellius, aulus
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Horace
# Matched author: horace
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Livy
# Matched author: livy
# Processing: Mela, Pomponius
# Matched author: mela, pomponius
# Processing: Martial
# Matched author: martial
# Processing: Lucretius Carus, Titus
# Matched author: lucretius carus, titus
# Processing: Lucretius Carus, Titus
# Matched author: lucretius carus, titus
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: seneca, lucius annaeus, approximately 4 b.c.-65 a.d.
# Processing: Silius Italicus, Tiberius Catius
# Matched author: silius italicus, tiberius catius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Prudentius, 348-
# Matched author: prudentius, 348-
# Processing: Propertius, Sextus
# Matched author: propertius, sextus
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Tibullus
# Matched author: tibullus
# Processing: Virgil.
# Matched author: virgil
# Processing: Virgil
# Matched author: virgil
# Processing: Guarino, Veronese, 1374-1460
# Matched author: guarino, veronese, 1374-1460
# Processing: Apuleius.
# Matched author: apuleius
# Processing: Commodianus
# Matched author: commodianus
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Lucas, Christian Theodor Ludwig.
# Matched author: lucas, bishop of túy, -approximately 1249
# Processing: Herbert, of Bosham, fl. 1162-1186.
# Matched author: herbert, of bosham, active 12th century
# Processing: Luther, Martin, 1483-1546.
# Matched author: luther, martin
# Processing: Somoogyi, Ambrosius, fl. 1604.
# Matched author: oláh, miklós, 1493-1568
# Processing: Benedict XIV, Pope, 1675-1758
# Matched author: benedict i, pope
# Processing: Stosch, Ferdinand, 1717-1780.
# Matched author: meister, ferdinand otto, 1828-1915
# Processing: Borový, Klement, 1838-1897
# Matched author: borino, giovanni battista
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Duns Scotus, John, approximately 1266-1308
# Matched author: duns scotus, john, approximately 1266-1308
# Processing: Osorio, Jeronymo, Bishop of Silves, 1506-1580.
# Matched author: hosius, of córdoba
# Processing: Luther, Martin, 1483-1546.
# Matched author: luther, martin
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Długosz, Jan, 1415-1480
# Matched author: maciej, z miechowa, 1457?-1523
# Processing: Assemani, Giuseppe Luigi, 1710?-1782.
# Matched author: asser, john
# Processing: Forcellini, Egidio, 1688-1768
# Matched author: forcellini, egidio, 1688-1768
# Processing: Vigiliis von Creutzenfeld, Stephan Hieronymus de.
# Matched author: otto i, bishop of freising, -1158
# Processing: Kühnöl, Christian Gottlieb, 1768-1841,
# Matched author: harless, gottlieb christoph, 1738-1815
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Livy
# Matched author: livy
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Albategnius., d. 920.
# Matched author: arbonius silo
# Processing: Ḥamzah al-Iṣfahānī, 893 or 894-970 or 971.
# Matched author: anaritius, -approximately 922
# Processing: Tertullian, approximately 160-approximately 230
# Matched author: tertullian
# Processing: Pliny, the Elder
# Matched author: pliny, the elder
# Processing: Lucretius Carus, Titus
# Matched author: lucretius carus, titus
# Processing: Milton, John, 1608-1674.
# Matched author: milton, john
# Processing: Horace
# Matched author: horace
# Processing: Ordericus Vitalis, 1075-1143?
# Matched author: ordericus vitalis
# Processing: Viger, François, 1590-1647.
# Matched author: victor, vitensis
# Processing: Livy.
# Matched author: livy
# Processing: Ambrose, Saint, Bishop of Milan, -397
# Matched author: ambrose, saint, bishop of milan
# Processing: Livy
# Matched author: livy
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Kepler, Johannes, 1571-1630.
# Matched author: kepler, johannes
# Processing: Lucan, 39-65
# Matched author: lucan
# Processing: Seneca, Lucius Annaeus, approximately 55 B.C.-approximately 39 A.D.
# Matched author: seneca, lucius annaeus, approximately 55 b.c.-approximately 39 a.d.
# Processing: Orzechowski, Stanisław Okszyc, 1513-1566 or 1567
# Matched author: miodoński, adam stefan, 1861-1913
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Zoega, Georg, 1755-1809
# Matched author: urba, karl franz
# Processing: Virgil
# Matched author: virgil
# Processing: Devarius, Matthaeus, b. 1505?
# Matched author: pacatus drepanius, latinus
# Processing: Horace
# Matched author: horace
# Processing: Persius
# Matched author: persius
# Processing: Tibullus.
# Matched author: tibullus
# Processing: Grotius, Hugo, 1583-1645
# Matched author: grotius, hugo, 1583-1645
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Abū al-Rabīʻ Sulaymān ibn ʻAbd Allāh al-Muwaḥḥid.
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Freytag, G. W.
# Matched author: frey, joseph, 1834-1910
# Processing: Suetonius, approximately 69-approximately 122
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Horace
# Matched author: horace
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Abū Tammām Ḥabīb ibn Aws al-Ṭāʼī, active 808-842
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Zwingli, Ulrich 1484-1531.
# Matched author: zwingli, ulrich, 1484-1531
# Processing: Valerius Maximus
# Matched author: valerius maximus
# Processing: Horace
# Matched author: horace
# Processing: Silius Italicus, Tiberius Catius
# Matched author: silius italicus, tiberius catius
# Processing: Statius, P. Papinius
# Matched author: statius, p. papinius (publius papinius)
# Processing: Bonafous, Norbert Alexandre, b. 1809.
# Matched author: polignac, melchior de, 1661-1742?
# Processing: Hüpenden, Ludwig Philipp.
# Matched author: ludwig, ernst, 1845-1912
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Livy
# Matched author: livy
# Processing: Kimmel, Ernst Julius, 1812-1846.
# Matched author: peter, hermann, 1837-1914
# Processing: Locke, John, 1632-1704
# Matched author: phreas, john, -1465
# Processing: Tertullian, approximately 160-approximately 230
# Matched author: tertullian
# Processing: Valerius Maximus
# Matched author: valerius maximus
# Processing: Nonius Marcellus, active 4th century
# Matched author: nonius marcellus
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: bacon, roger, 1214?-1294
# Processing: Suetonius, approximately 69-approximately 122
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Livy
# Matched author: livy
# Processing: Muczkowski, Józef, 1795-1858
# Matched author: muczkowski, antoni, 1807-1852
# Processing: Avitus, Alcimus Ecdicius, Saint, d. 518.
# Matched author: avitus, saint, bishop of vienne
# Processing: Livy.
# Matched author: livy
# Processing: Justinus, Marcus Junianus
# Matched author: justinus, marcus junianus
# Processing: Phaedrus
# Matched author: phaedrus
# Processing: David, von Augsburg, -1271
# Matched author: chytraeus, david, 1531-1600
# Processing: Muret, Marc-Antoine, 1526-1585
# Matched author: muret, marc-antoine, 1526-1585
# Processing: Petrarca, Francesco, 1304-1374
# Matched author: petrarca, francesco
# Processing: Horace.
# Matched author: horace
# Processing: Voltaire, 1694-1778
# Matched author: descartes, rené
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Keller, Friedrich Ludwig von, 1799-1860.
# Matched author: keller, otto, 1838-1927
# Processing: Balde, Jakob, 1604-1668
# Matched author: balde, jakob
# Processing: Balde, Jakob, 1604-1668
# Matched author: balde, jakob
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Bothe, Friedrich Heinrich, 1771-1855.
# Matched author: lindenbrog, heinrich, 1570-1642
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Duns Scotus, John, approximately 1266-1308
# Matched author: duns scotus, john, approximately 1266-1308
# Processing: Blois, Louis de, 1506-1566.
# Matched author: henry, of blois, bishop of winchester, approximately 1090-1171
# Processing: Clement, Joannes Franciscus, 1823-1892.
# Matched author: jan, ludwig von 1807-1869
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Pliny, the Younger
# Matched author: pliny, the younger
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Pliny, the Elder
# Matched author: pliny, the elder
# Processing: Pliny, the Younger
# Matched author: pliny, the younger
# Processing: Spohn, Friedrich August Wilhelm, 1792-1824
# Matched author: krohn, fritz, 1873-1941
# Processing: Viger, François, 1590-1647
# Matched author: victor, vitensis
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Valerius Maximus,
# Matched author: valerius maximus
# Processing: Caesar, Julius
# Matched author: caesar, julius
# Processing: Horace
# Matched author: horace
# Processing: Frontinus, Sextus Julius.
# Matched author: frontinus, sextus julius
# Processing: Horace
# Matched author: horace
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Madvig, J. N. 1804-1886
# Matched author: madvig, j. n. (johan nikolai), 1804-1886
# Processing: Blois, Louis de, 1506-1566
# Matched author: henry, of blois, bishop of winchester, approximately 1090-1171
# Processing: Ghiringhello, Giuseppe.
# Matched author: landulf, of milan
# Processing: Vlis, Christian Jacob van der.
# Matched author: vliet, joannes van der, 1847-1902
# Processing: Vitruvius Pollio
# Matched author: vitruvius pollio
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Capaccio, Giulio Cesare, 1552-1634
# Matched author: braccesi, alessandro, 1445-1503
# Processing: Thiele, Georg, 1866-1917.
# Matched author: müller, moritz, 1854-
# Processing: Tibullus
# Matched author: tibullus
# Processing: Victor, Sextus Aurelius
# Matched author: victor, sextus aurelius
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil
# Matched author: virgil
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Pliny, the Younger.
# Matched author: pliny, the younger
# Processing: Valerius Flaccus, Gaius, active 1st century
# Matched author: valerius flaccus, gaius
# Processing: Virgil
# Matched author: virgil
# Processing: Horace
# Matched author: horace
# Processing: Jacob, J. F.
# Matched author: jacob, émile, 1867-1953
# Processing: Cyprian, Saint, Bishop of Carthage
# Matched author: cyprian, saint, bishop of carthage
# Processing: Livy
# Matched author: livy
# Processing: Valerius Maximus
# Matched author: valerius maximus
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil
# Matched author: virgil
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Kimchi, David, 1160?-1235.
# Matched author: mattias, -1350
# Processing: Quintilian
# Matched author: quintilian
# Processing: Petrarca, Francesco, 1304-1374
# Matched author: petrarca, francesco
# Processing: Agassiz, Louis, 1807-1873.
# Matched author: grégoire, l. (louis), 1819-1897
# Processing: Rørdam, Thomas Skat, 1832-
# Matched author: foerster, richard, 1843-1922
# Processing: Kühnöl, Christian Gottlieb, 1768-1841,
# Matched author: harless, gottlieb christoph, 1738-1815
# Processing: Virgil
# Matched author: virgil
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Gregory, Saint, Bishop of Tours, 538-594
# Matched author: gregory, bishop of tours, saint
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Endlicher, István László, 1804-1849.
# Matched author: endt, johannes
# Processing: Pliny, the Elder
# Matched author: pliny, the elder
# Processing: Lucretius Carus, Titus
# Matched author: lucretius carus, titus
# Processing: Rossbach, August, 1823-1898.
# Matched author: rossbach, august, 1823-1898
# Processing: Möller, Karl Rudolf, 1885-
# Matched author: schöll, rudolf, 1844-1893
# Processing: Hoeufft, Jacob Henrik, 1756-1843.
# Matched author: heiberg, j. l. (johan ludvig), 1854-1928
# Processing: Livy.
# Matched author: livy
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Tacitus, Cornelius
# Matched author: tacitus, cornelius
# Processing: Fuxhoffer, Damianus.
# Matched author: schweickhofer, johannes
# Processing: Keil, Heinrich, 1822-1894
# Matched author: keil, heinrich, 1822-1894
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Belostenec, Ivan, 1595-1675.
# Matched author: andronicus, matthaeus
# Processing: Vel, Caspar Ursinus, 1493-1538.
# Matched author: vel, caspar ursinus, 1493-1538
# Processing: Kerner von Marilaun, Anton, 1831-1898.
# Matched author: bèze, théodore de, 1519-1605
# Processing: Maratti, Giovanni Francesco.
# Matched author: victorius, marianus, approximately 1485-1572
# Processing: Īshō y̐abh III, Patriarch of the Nestorians, -657 or 658.
# Matched author: nestorius, patriarch of constantinople
# Processing: Gregory, of Catino, active 1100.
# Matched author: augustine, saint, archbishop of canterbury
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: seneca, lucius annaeus, approximately 4 b.c.-65 a.d.
# Processing: Martial.
# Matched author: martial
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Hrotsvitha, approximately 935-approximately 975.
# Matched author: hrotsvitha
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: seneca, lucius annaeus, approximately 4 b.c.-65 a.d.
# Processing: Serenus Sammonicus, Quintus.
# Matched author: serenus sammonicus, quintus
# Processing: Marcellus, Empiricus.
# Matched author: marcellus, empiricus
# Processing: Tkalčić, Ivan Krstitelj, 1840-1904,
# Matched author: kukuljević sakcinski, ivan, 1816-1889
# Processing: Ulpianus, Domitius, approximately 160-228.
# Matched author: ulpianus, domitius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Horace.
# Matched author: horace
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Firmicus Maternus, Julius.
# Matched author: firmicus maternus, julius
# Processing: Suetonius, approximately 69-approximately 122.
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Tibullus.
# Matched author: tibullus
# Processing: Pliny, the Elder.
# Matched author: pliny, the elder
# Processing: Valerius Maximus.
# Matched author: valerius maximus
# Processing: Varro, Marcus Terentius.
# Matched author: varro, marcus terentius
# Processing: Vegetius Renatus, Flavius.
# Matched author: vegetius renatus, flavius
# Processing: Horace.
# Matched author: horace
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Martial.
# Matched author: martial
# Processing: Vives, Juan Luis, 1492-1540.
# Matched author: vives, juan luis, 1492-1540
# Processing: Keats, John, 1795-1821.
# Matched author: keuchenius, robertus, 1636-1673
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Glaeser, Friedrich, classicist.
# Matched author: gläser, carl eduard
# Processing: Schwabe, Ludwig von, 1835-1908.
# Matched author: scheibe, karl friedrich, 1812-1869
# Processing: Grimm, Carl Ludwig Wilibald, 1807-1891.
# Matched author: müller, c. f. w. (carl friedrich wilhelm), 1830-1903
# Processing: Müller, Lucian, 1836-1898.
# Matched author: müller, lucian, 1836-1898
# Processing: Müller, Lucian, 1836-1898.
# Matched author: müller, lucian, 1836-1898
# Processing: Andreas, Capellanus.
# Matched author: andreas, capellanus
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Suetonius, approximately 69-approximately 122.
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: valerius flaccus, gaius
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Duns Scotus, John, ca. 1266-1308.
# Matched author: duns scotus, john, approximately 1266-1308
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Phaedrus.
# Matched author: phaedrus
# Processing: Cicero, Marcus Tullius
# Matched author: cicero, marcus tullius
# Processing: Florus, Lucius Annaeus.
# Matched author: florus, lucius annaeus
# Processing: Miekley, Walther, 1876-
# Matched author: willes, richard, active 1558-1573
# Processing: Ahlgrimm, Paul.
# Matched author: neckam, alexander
# Processing: Gronovius, Joannes Fredericus, 1611-1671.
# Matched author: gronovius, joannes fredericus, 1611-1671
# Processing: Pliny, the Younger.
# Matched author: pliny, the younger
# Processing: Pliny, the Younger.
# Matched author: pliny, the younger
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Tacticus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: valerius flaccus, gaius
# Processing: Lucan, 39-65.
# Matched author: lucan
# Processing: Lucan, 39-65.
# Matched author: lucan
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Ampelius, Lucius.
# Matched author: ampelius, lucius
# Processing: Florus, Lucius Annaeus.
# Matched author: florus, lucius annaeus
# Processing: Friedlaender, Ludwig, 1824-1909.
# Matched author: friedlaender, ludwig, 1824-1909
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Slijpen, Aloisius Petrus Hubertus Antonius.
# Matched author: john paul ii, pope, 1920-2005
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Altkamp, Karl.
# Matched author: brieger, adolf, 1832-1912
# Processing: Sedulius, Scotus, active 848-860.
# Matched author: sedulius, scotus, active 848-860
# Processing: Stanko, J.
# Matched author: stangl, thomas, 1854-1921
# Processing: Némethy, Geza.
# Matched author: némethy, géza, 1865-1937
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Albertano, da Brescia, active 13th century.
# Matched author: albertano, da brescia, active 13th century
# Processing: Schelemius, Henninius, active 1600.
# Matched author: birck, sixt, 1500-1554
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Suetonius, approximately 69-approximately 122.
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Suetonius, approximately 69-approximately 122.
# Matched author: suetonius, approximately 69-approximately 122
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Ramain, Georges.
# Matched author: harvey, william, 1578-1657
# Processing: Brix, Ernst Julius, 1815-
# Matched author: brummer, jacob
# Processing: Hublocher, J. B.
# Matched author: bernegger, matthias, 1582-1640
# Processing: Agahd, Reinhold Hermann August.
# Matched author: adler, elmer, 1884-1962
# Processing: Propertius, Sextus.
# Matched author: propertius, sextus
# Processing: Virgil.
# Matched author: virgil
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Friedrich, Wilhelm Ludwig, 1877-
# Matched author: döring, f. w. (friedrich wilhelm), 1757-1837
# Processing: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D.
# Matched author: seneca, lucius annaeus, approximately 4 b.c.-65 a.d.
# Processing: Keil, Henricus, 1822-1894.
# Matched author: keil, heinrich, 1822-1894
# Processing: Hrotsvitha, approximately 935-approximately 975.
# Matched author: hrotsvitha
# Processing: Kreussler, Otto.
# Matched author: krahner, leopold, 1810-1884
# Processing: Sydow, Rudolf, 1857-
# Matched author: peerlkamp, petrus hofman, 1786-1865
# Processing: Croiset, Maurice, 1846-1935.
# Matched author: chifflet, claude, 1541-1580
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Statius, P. Papinius
# Matched author: statius, p. papinius (publius papinius)
# Processing: Wilamowitz-Moellendorff, Ulrich von, 1848-1931.
# Matched author: wernsdorf, johann christian, 1723-1793
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Orosius, Paulus.
# Matched author: orosius, paulus
# Processing: Lambert, von Hersfeld, -1088?
# Matched author: lambert, von hersfeld
# Processing: Regell, Paul.
# Matched author: paulinus, of pella
# Processing: Bede, the Venerable, Saint, 673-735.
# Matched author: bede, the venerable, saint
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Ruusbroec, Jan van, 1293-1381.
# Matched author: ruusbroec, jan van 1293-1381
# Processing: Caesarius, of Heisterbach, approximately 1180-approximately 1240.
# Matched author: caesarius, of heisterbach, approximately 1180-approximately 1240
# Processing: Kholodni͡ak, I. I. 1857-1913.
# Matched author: scholier, pieter 1582-1635
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Tomkowicz, Stanisław.
# Matched author: cybulski, stephan, 1858-1937
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Kleinguenther, Hermann, 1865-
# Matched author: hense, otto, 1845-1931
# Processing: Horace.
# Matched author: horace
# Processing: Persius.
# Matched author: persius
# Processing: Cyprian, Saint, Bishop of Carthage.
# Matched author: cyprian, saint, bishop of carthage
# Processing: Tertullian, approximately 160-approximately 230
# Matched author: tertullian
# Processing: Apuleius.
# Matched author: apuleius
# Processing: Tibullus.
# Matched author: tibullus
# Processing: Ammianus Marcellinus.
# Matched author: ammianus marcellinus
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Gellius, Aulus
# Matched author: gellius, aulus
# Processing: Livy.
# Matched author: livy
# Processing: Denis the Carthusian, 1402-1471.
# Matched author: dionysius, of alexandria, saint
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Gellius, Aulus.
# Matched author: gellius, aulus
# Processing: Calvin, Jean, 1509-1564.
# Matched author: calvin, jean, 1509-1564
# Processing: Apuleius.
# Matched author: apuleius
# Processing: Livy
# Matched author: livy
# Processing: Boethius, -524.
# Matched author: boethius, -524
# Processing: Peter Lombard, Bishop of Paris, approximately 1100-1160.
# Matched author: peter lombard, bishop of paris
# Processing: Ammianus Marcellinus.
# Matched author: ammianus marcellinus
# Processing: Buxtorf, Johann, 1564-1629.
# Matched author: trotzendorf, valentin, 1490-1556
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Virgil.
# Matched author: virgil
# Processing: Albertano, da Brescia, active 13th century.
# Matched author: albertano, da brescia, active 13th century
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Livy.
# Matched author: livy
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Schimmelpfenning, Carolus Adolphus.
# Matched author: melissus, paulus, 1539-1602
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: valerius flaccus, gaius
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil.
# Matched author: virgil
# Processing: Virgil.
# Matched author: virgil
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Pliny, the Younger the Younger.
# Matched author: pliny, the younger
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Moravia (Czechoslovakia) Soud zemský.
# Matched author: jerome, of moravia, active 1272-1304
# Processing: Valerius Maximus.
# Matched author: valerius maximus
# Processing: Lachmann, Karl, 1793-1851.
# Matched author: lachmann, karl, 1793-1851
# Processing: Mendes, Affonso, Patriarch of Ethiopia, 1579-1656.
# Matched author: embrico, of mainz
# Processing: Łaski, Jan, 1499-1560
# Matched author: piekosiński, franciszek, 1844-1906
# Processing: Vega, Andreas de, 1498-1549.
# Matched author: vega, garcilaso de la
# Processing: Baconthorpe, John, -1346.
# Matched author: baconthorpe, john, -1346
# Processing: Ricardus, de Mediavilla, approximately 1249-1308?
# Matched author: richer, of senones
# Processing: Catholic Church.
# Matched author: john xxi, pope, -1277
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Tertullian, approximately 160-approximately 230.
# Matched author: tertullian
# Processing: Tibullus.
# Matched author: tibullus
# Processing: Horace
# Matched author: horace
# Processing: Orsi, Roberto, -approximately 1496.
# Matched author: titi, roberto, 1551-1609
# Processing: William, of Malmesbury, approximately 1090-1143.
# Matched author: william, of malmesbury
# Processing: Simeon, of Durham, -approximately 1130.
# Matched author: thomas monumetensis ca. 1170
# Processing: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Matched author: velleius paterculus
# Processing: Cassian, John, approximately 360-approximately 435.
# Matched author: cassian, john
# Processing: Eugippius.
# Matched author: eugippius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Otto I, Bishop of Freising, -1158.
# Matched author: otto i, bishop of freising, -1158
# Processing: Berger, Samuel, 1843-1900.
# Matched author: gott, samuel, 1613-1671
# Processing: Rabanus Maurus, Archbishop of Mainz, 784?-856.
# Matched author: rabanus maurus, archbishop of mainz, 784?-856
# Processing: Valturio, Roberto, 1405-1475.
# Matched author: vittorino, da feltre, 1378-1446
# Processing: Horace.
# Matched author: horace
# Processing: Virgil
# Matched author: virgil
# Processing: Virgil.
# Matched author: virgil
# Processing: Livy.
# Matched author: livy
# Processing: Długosz, Jan, 1415-1480.
# Matched author: maciej, z miechowa, 1457?-1523
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Ekkehard IV, approximately 980-approximately 1060.
# Matched author: ekkehard iv, approximately 980-approximately 1060
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Arminius, Jacobus, 1560-1609.
# Matched author: jansenius, cornelius, 1510-1576
# Processing: Pietrasanta, Silvestro, 1590-1647.
# Matched author: petrarca, francesco
# Processing: Haurech, Julianus Aurelius.
# Matched author: ennius, sex.
# Processing: Bottari, Giovanni Gaetano, 1689-1775.
# Matched author: bottoni, bernardo, -1266
# Processing: Augustine, Saint, Bishop of Hippo.
# Matched author: augustine, of hippo, saint, 354-430
# Processing: Goltzius, Hubert, 1526-1583.
# Matched author: hertz, martin
# Processing: Apuleius.
# Matched author: apuleius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# ...
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Klotz, Christian Adolph, 1738-1771.
# Matched author: klotz, alfred, 1874-1956
# Processing: Nepos, Cornelius.
# Matched author: nepos, cornelius
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Virgil.
# Matched author: virgil
# Processing: Virgil.
# Matched author: virgil
# Processing: Janus, Secundus, 1511-1536.
# Matched author: janus, secundus
# Processing: Propertius, Sextus.
# Matched author: propertius, sextus
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Salvian, of Marseilles, approximately 400-approximately 480
# Matched author: salvian, of marseilles
# Processing: Horace.
# Matched author: horace
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Castellion, Sébastien, 1515-1563.
# Matched author: cortesi, paolo, 1465-1510
# Processing: Livy.
# Matched author: livy
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Horace.
# Matched author: horace
# Processing: Virgil.
# Matched author: virgil
# Processing: Valerius Flaccus, Gaius, active 1st century.
# Matched author: valerius flaccus, gaius
# Processing: Pliny, the Elder.
# Matched author: pliny, the elder
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Palingenio Stellato, Marcello, approximately 1500-approximately 1543
# Matched author: palingenio stellato, marcello, approximately 1500-approximately 1543
# Processing: Virgil.
# Matched author: virgil
# Processing: Livy.
# Matched author: livy
# Processing: Vossius, Gerardus Joannes, 1577-1649.
# Matched author: vossius, gerardus joannes, 1577-1649
# Processing: Livy.
# Matched author: livy
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Giraldus, Cambrensis, 1146?-1223?
# Matched author: giraldus, cambrensis
# Processing: Propertius, Sextus.
# Matched author: propertius, sextus
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Virgil.
# Matched author: virgil
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Sallust, 86 B.C.-34 B.C.
# Matched author: sallust
# Processing: Horace.
# Matched author: horace
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Nithard, -844?
# Matched author: nithard, -844?
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Virgil.
# Matched author: virgil
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Ovid, 43 B.C.-17 A.D. or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Wesseling, Petrus, 1692-1764.
# Matched author: wessely, carl, 1860-1931
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Sedulius, 5th cent.
# Matched author: sedulius, active 5th century
# Processing: Vossius, Gerardus Joannes, 1577-1649.
# Matched author: vossius, gerardus joannes, 1577-1649
# Processing: Amarcius, active 11th century
# Matched author: amarcius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Catullus, Gaius Valerius.
# Matched author: catullus, gaius valerius
# Processing: Catullus, Gaius Valerius
# Matched author: catullus, gaius valerius
# Processing: Sallust, 86-34 B.C.
# Matched author: sallust
# Processing: Virgil
# Matched author: virgil
# Processing: Ibn ʻArabshāh, Aḥmad ibn Muḥammad, 1392-1450
# Matched author: avicenna, 980-1037
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Horace.
# Matched author: horace
# Processing: Hagen, Hermann, 1844-1898,
# Matched author: hagen, hermann, 1844-1898
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Hilary, Saint, Bishop of Poitiers, d. 367?
# Matched author: hilary, saint, bishop of poitiers, -367?
# Processing: Augustine, Saint, Bishop of Hippo.
# Matched author: augustine, of hippo, saint, 354-430
# Processing: Pliny, the Younger.
# Matched author: pliny, the younger
# Processing: Pliny, the Elder.
# Matched author: pliny, the elder
# Processing: Valerius Flaccus, Gaius, 1st cent.
# Matched author: valerius flaccus, gaius
# Processing: Valerius Flaccus, Gaius, 1st cent.
# Matched author: valerius flaccus, gaius
# Processing: Viger, François, 1590-1647.
# Matched author: victor, vitensis
# Processing: Sallust, 86-34 B.C.
# Matched author: sallust
# Processing: Lucan, 39-65.
# Matched author: lucan
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Haymarus Monachus, d. 1202.
# Matched author: haimo, of auxerre, -approximately 855
# Processing: Virgil.
# Matched author: virgil
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Caesar, Julius.
# Matched author: caesar, julius
# Processing: Henricus, de Hervordia, d. 1370.
# Matched author: henry iii, king of france, 1551-1589
# Processing: Propertius, Sextus.
# Matched author: propertius, sextus
# Processing: Janus, Secundus, 1511-1536.
# Matched author: janus, secundus
# Processing: Statius, P. Papinius
# Matched author: statius, p. papinius (publius papinius)
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Bacon, Roger, 1214?-1294.
# Matched author: bacon, roger, 1214?-1294
# Processing: Abū Miḥjan al-Thaqafī, fl. 629-637.
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Olivet, Pierre-Joseph Thoulier, abbé d', 1682-1768.
# Matched author: fleury, julien, 1647-1725
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Sallust, 86-34 B.C.
# Matched author: sallust
# Processing: Horace.
# Matched author: horace
# Processing: Virgil.
# Matched author: virgil
# Processing: Dymmok, Roger, fl. 1395.
# Matched author: thomas monumetensis ca. 1170
# Processing: Livy.
# Matched author: livy
# Processing: Virgil.
# Matched author: virgil
# Processing: Virgil.
# Matched author: virgil
# Processing: Quintilian.
# Matched author: quintilian
# Processing: Thomas, de Cantimpré, ca. 1200-ca. 1270.
# Matched author: thomas of celano 1190-1260
# Processing: Thomas, of Ely, fl. 1174.
# Matched author: thomas of celano 1190-1260
# Processing: Graetz, Heinrich, 1817-1891.
# Matched author: graevius, joannes georgius, 1632-1703
# Processing: Storr, Rayner.
# Matched author: stretzinger, thomas, -1523
# Processing: Hoffmann, Emanuel, 1825-1900.
# Matched author: hoffmann, christian gottfried, 1692-1735
# Processing: Petronius Arbiter.
# Matched author: petronius arbiter
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Dubrovnik (Republic)
# Matched author: columbus, christopher
# Processing: Schuster, Ildefonso, 1880-1954.
# Matched author: ildephonsus, saint
# Processing: Dietrich, von Nieheim, ca. 1340-1418.
# Matched author: loër, dirk, approximately 1495-1554
# Processing: Suárez, Francisco, 1548-1617.
# Matched author: suárez, francisco, 1548-1617
# Processing: Vries, Hugo de, 1848-1935.
# Matched author: laemmer, hugo, 1835-1918
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Curtius Rufus, Quintus.
# Matched author: curtius rufus, quintus
# Processing: Cicero, Marcus Tullius.
# Matched author: cicero, marcus tullius
# Processing: Vinkesteyn, Cornelius Joannes.
# Matched author: jansenius, cornelius, 1510-1576
# Processing: Wycliffe, John, d. 1384.
# Matched author: wycliffe, john, -1384
# Processing: Buchanan, David, 1595?-1652?
# Matched author: buchanan, george
# Processing: Munkelif, Norway. (Benedictine Monastery)
# Matched author: notger, bishop of liège
# Processing: Priscianus, Theodorus.
# Matched author: priscianus, theodorus
# Processing: Heydenreich, Wilhelm, 1875-
# Matched author: hildebrand, gustav friedrich, 1812-1869
# Processing: Sallust, 86-34 B.C.
# Matched author: sallust
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Brink, Barend ten, 1803-1875.
# Matched author: brinkmann, august, 1863-1923
# Processing: Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# Matched author: velleius paterculus
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Campion, Thomas, 1567-1620.
# Matched author: campion, thomas
# Processing: Moritz, C.
# Matched author: müller, moritz, 1816-1895
# Processing: Palingenio Stellato, Marcello, ca. 1500-ca. 1543.
# Matched author: palingenio stellato, marcello, approximately 1500-approximately 1543
# Processing: Milchsack, Gustav, 1850-1919.
# Matched author: seeck, otto, 1850-1921
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Horace.
# Matched author: horace
# Processing: Juvenal.
# Matched author: juvenal
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Lucretius Carus, Titus.
# Matched author: lucretius carus, titus
# Processing: Manilius, Marcus.
# Matched author: manilius, marcus
# Processing: Rutilius Lupus, Publius.
# Matched author: rutilius lupus, publius
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Ovid, 43 B.C.-17 or 18 A.D.
# Matched author: ovid, 43 b.c.-17 a.d. or 18 a.d.
# Processing: Persius.
# Matched author: persius
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Livy.
# Matched author: livy
# Processing: Lucan, 39-65.
# Matched author: lucan
# Processing: Petermann, August, 1818-
# Matched author: peter, hermann, 1837-1914
# Processing: Tacitus, Cornelius.
# Matched author: tacitus, cornelius
# Processing: Portus, Aemilius, 1550-1614 or 15.
# Matched author: alanus, de insulis
# Processing: Linné, Carl von, 1707-1778
# Matched author: linné, carl von, 1707-1778
# Processing: Petau, Denis, 1583-1652.
# Matched author: philippe de prétot, étienne-andré, 1710-1787
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Knabenbauer, Joseph, 1839-1911.
# Matched author: krahner, leopold, 1810-1884
# Processing: Thomas, à Kempis, 1380-1471.
# Matched author: thomas, à kempis, 1380-1471
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Processing: Persius.
# Matched author: persius
# Processing: Jaʻfarī, Ṣāliḥ ibn al-Ḥusayn, d. 1269 or 70., جعفري، صالح بن الحسين.
# Matched author: rāzī, abū bakr muḥammad ibn zakarīyā, 865?-925?
# Processing: Unknown
# Matched author: alan, of tewkesbury
# Done with processing authors and titles.
#                                               author  \
# 0                    Du Creux, François, 1596?-1666.
# 1                      Meyer, Ernst H. F. 1791-1858.
# 2                       Laet, Joannes de, 1593-1649.
# 3                                     Caesar, Julius
# 4                                            Unknown
# 5                       Drexel, Jeremias, 1581-1638,
# 6                     Kircher, Athanasius, 1602-1680
# 7  Hincmar, Archbishop of Reims, approximately 80...
# 8                       Acosta, José de, 1540-1600,
# 9                      Lessius, Leonardus, 1554-1623
#
#                                   normalized_author  \
# 0                        du creux francois 15961666
# 1                          meyer ernst h f 17911858
# 2                          laet joannes de 15931649
# 3                                     caesar julius
# 4                                           unknown
# 5                          drexel jeremias 15811638
# 6                       kircher athanasius 16021680
# 7  hincmar archbishop of reims approximately 806882
# 8                           acosta jose de 15401600
# 9                        lessius leonardus 15541623
#
#              deterministic_author                    fuzzy_author  \
# 0                            None                            None
# 1                            None                            None
# 2                            None                            None
# 3                            None                  caesar, julius
# 4                            None                            None
# 5                            None                            None
# 6  kircher, athanasius, 1602-1680  kircher, athanasius, 1602-1680
# 7                            None                            None
# 8     acosta, josé de, 1540-1600     acosta, josé de, 1540-1600
# 9                            None                            None
#
#    fuzzy_author_score                     distilbert_author  \
# 0                 0.0       graux, charles henri, 1852-1882
# 1                 0.0             meyer, wilhelm, 1845-1917
# 2                 0.0                   lawrence, of novara
# 3                 1.0                        caesar, julius
# 4                 0.0                   alan, of tewkesbury
# 5                 0.0          dorpius, martinus, 1485-1525
# 6                 1.0        kircher, athanasius, 1602-1680
# 7                 0.0          hincmar, archbishop of reims
# 8                 1.0           acosta, josé de, 1540-1600
# 9                 0.0  lessing, gotthold ephraim, 1729-1781
#
#    distilbert_author_score
# 0                 0.177464
# 1                 0.999956
# 2                 0.156866
# 3                 0.999986
# 4                 0.110270
# 5                 0.521497
# 6                 0.999991
# 7                 0.999999
# 8                 0.999997
# 9                 0.985865

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Basic facts about the input data

# %%
# Number of rows in the input dataframe
num_rows = len(input_df)
print(f"Number of rows in the input dataframe: {num_rows}")
# Out:
# Number of rows in the input dataframe: 13446

# %%
# Get the number of unique authors in the input dataframe
unique_authors = input_df['author'].nunique()
print(f"Number of unique authors in the input dataframe: {unique_authors}")
# Out:
# Number of unique authors in the input dataframe: 5515

# %%
# Get the number of unique authors with more than one row in the input dataframe
duplicate_authors = input_df['author'].value_counts()
duplicate_authors = duplicate_authors[duplicate_authors > 1]

print(f"Number of unique authors with more than one row in the input dataframe: {len(duplicate_authors)}")

# Get the number of unique authors with only one row in the input dataframe
single_authors = input_df['author'].value_counts()
single_authors = single_authors[single_authors == 1]
print(f"Number of unique authors with only one row in the input dataframe: {len(single_authors)}")
# Out:
# Number of unique authors with more than one row in the input dataframe: 1499
# Number of unique authors with only one row in the input dataframe: 4016

# %%
# Display the top ten duplicate authors by number of rows
print("Top ten duplicate authors by number of rows:")
print(duplicate_authors.head(10))
# Out:
# Top ten duplicate authors by number of rows:
# author
# Unknown                             611
# Cicero, Marcus Tullius.             339
# Horace.                             216
# Livy.                               205
# Virgil.                             174
# Tacitus, Cornelius.                 160
# Cicero, Marcus Tullius              157
# Ovid, 43 B.C.-17 A.D. or 18 A.D.    129
# Horace                              125
# Lucretius Carus, Titus.             109
# Name: count, dtype: int64

# %%
# Display the bottom ten duplicate authors by number of rows
print("Bottom ten duplicate authors by number of rows:")
print(duplicate_authors.tail(10))
# Out:
# Bottom ten duplicate authors by number of rows:
# author
# Bersuire, Pierre, ca.1290-1362    2
# Bastgen, Philip.                  2
# Czerner, Bartholomaeus.           2
# Arias de Mesa, Fernando.          2
# Erasmus, Desiderius, d. 1536.     2
# Socini, Mariano, Senior.          2
# Tancredi, Vincenzo.               2
# Magro, Jacobo.                    2
# Ullrich, Richard, 1866-           2
# Froitzheim, Johann, 1847-         2
# Name: count, dtype: int64

# %% [markdown]
# The input dataframe has 13,446 rows of data.
# There are 5,515 unique author names.
# 1,499 of those unique authors appear in more than one row.
# 4,016 of those unique authors appear only once in the dataframe.
#
# "Unique" means that the name form is unique. Individual authors often have more than one name form (e.g., "Cicero, Marcus Tullius." and "Cicero, Marcus Tullius" above).
#
# The top five "unique" author in the input dataframe, aside from "unknown" are well-known authors from the Classical era:
#
# 1. Marcus Tullius Cicero
# 2. Horace
# 3. Livy
# 4. Virgil
# 5. Tacitus
#
# The bottom five "unique" authors with more than one row tend to be more obscure and from the Neo-Latin era:
#
# 1495. Socini, Mariano, Senior.
# 1496. Tancredi, Vincenzo.
# 1497. Magro, Jacobo.
# 1498. Ullrich, Richard, 1866-
# 1499. Froitzheim, Johann, 1847-

# %% [markdown]
# ## Examining the Output

# %%
# Get the number of unique authors with more than one row in the output dataframe
duplicate_authors = output_df['normalized_author'].value_counts()
duplicate_authors = duplicate_authors[duplicate_authors > 1]

print(f"Number of unique authors with more than one row in the input dataframe: {len(duplicate_authors)}")

# Display the top ten duplicate authors by number of rows
print("Top ten duplicate authors by number of rows:")
print(duplicate_authors.head(10))

# Display the bottom ten duplicate authors by number of rows
print("Bottom ten duplicate authors by number of rows:")
print(duplicate_authors.tail(10))
# Out:
# Number of unique authors with more than one row in the input dataframe: 1472
# Top ten duplicate authors by number of rows:
# normalized_author
# unknown                     611
# cicero marcus tullius       496
# horace                      341
# livy                        297
# virgil                      252
# tacitus cornelius           246
# lucretius carus titus       151
# ovid 43 bc17 ad or 18 ad    131
# catullus gaius valerius     110
# quintilian                  104
# Name: count, dtype: int64
# Bottom ten duplicate authors by number of rows:
# normalized_author
# chalkokondyles laonikos ca 1430ca 1490    2
# alvares manuel 15261583                   2
# keats john 17951821                       2
# brink barend ten 18031875                 2
# mace alcide                               2
# drexel jeremias 15811638                  2
# otto carl eduard 17951869                 2
# christ johann friedrich 17001756          2
# ludwich arthur 18401920                   2
# nakatenus wilhelm 16171682                2
# Name: count, dtype: int64

# %% [markdown]
# The first step is to deduplicate the output based on the `normalized_author` column. This will help with the problem of several name forms for single authors.

# %%
# Deduplicate the output dataframe by normalized_author column
output_df_dedup = output_df.drop_duplicates(subset=['normalized_author'])
# Number of rows in the deduplicated output dataframe
num_rows_dedup = len(output_df_dedup)
print(f"Number of rows in the deduplicated output dataframe: {num_rows_dedup}")
# Out:
# Number of rows in the deduplicated output dataframe: 4779

# %%
# Make a dataframe from rows with a match in the deterministic author column
deterministic_matches = output_df_dedup[
    (output_df_dedup['deterministic_author'].notnull() & (output_df_dedup['deterministic_author'] != "None"))]

# Get the length of the deterministic matches dataframe
deterministic_matches_length = len(deterministic_matches)
print(f"Number of rows with a deterministic author match: {deterministic_matches_length}")
# Out:
# Number of rows with a deterministic author match: 491

# %%
# Make a dataframe from rows with a match with highest confidence in the fuzzy author column
fuzzy_matches = output_df_dedup[output_df_dedup['fuzzy_author_score'] == 1.0]
# Filter the rows in the dataframe to unique values in the normalized author column
fuzzy_matches_unique = fuzzy_matches['normalized_author'].nunique()
# Get the length of the fuzzy matches dataframe
fuzzy_matches_length = len(fuzzy_matches)
print(f"Number of rows with highest confidence in fuzzy matching: {fuzzy_matches_length}")
# Out:
# Number of rows with highest confidence in fuzzy matching: 526

# %%
# Make a dataframe from rows with a match of highest confidence in the distilbert_author_score column
inference_matches = output_df_dedup[output_df_dedup['distilbert_author_score'] >= 0.999957]
# Get the length of the inference_matches dataframe
inference_matches_length = len(inference_matches)
print(f"Number of rows in the inference matches dataframe: {inference_matches_length}")
# Out:
# Number of rows in the inference matches dataframe: 615

# %%
# Coverage
deterministic_coverage = (output_df_dedup['deterministic_author'].notnull() & (output_df_dedup['deterministic_author'] != "None")).mean()
print(f"Deterministic matching coverage: {deterministic_coverage:.2%}")

fuzzy_coverage = (output_df_dedup['fuzzy_author_score'] == 1.0).mean()
print(f"Fuzzy matching high-confidence coverage: {fuzzy_coverage:.2%}")

distilbert_coverage = (output_df_dedup['distilbert_author_score'] >= 0.9901).mean()
print(f"DistilBERT high-confidence coverage: {distilbert_coverage:.2%}")
# Out:
# Deterministic matching coverage: 10.27%
# Fuzzy matching high-confidence coverage: 11.01%
# DistilBERT high-confidence coverage: 25.19%

# %% [markdown]
# The deterministic algorithm matched 491 of the unique authors in the original dataset. That is not surprising, since a one-to-one comparison is very conservative and depends on the exact same name form appearing in the input data.
#
# The probabilistic matching algorithm matched 526 of the unique authors in the original dataset. That, too, is not surprising, since fuzzy matching takes into account slight variations in spelling.
#
# The machine learning model 615 unique authors, when the optimal confidence score of 0.999957 is used as a cutoff. The next several cells explain how I arrived at that optimal confidence score.

# %% [markdown]
# ## Comparison: Model vs. Deterministic Matching

# %%
# Filter the results to show the intersection of deterministic matches that aren't "None" and model matches that are greater than 0.9
high_confidence_deterministic = output_df[
    (output_df['deterministic_author'].notnull() & (output_df['deterministic_author'] != "None")) &
    (output_df['distilbert_author_score'] > 0.9901)
]
print(f"Number of rows with high confidence matches: {len(high_confidence_deterministic)}")
display(high_confidence_deterministic.head(10))
# Out:
# Number of rows with high confidence matches: 4283
#                                  author              normalized_author  \
# 6        Kircher, Athanasius, 1602-1680    kircher athanasius 16021680
# 8          Acosta, José de, 1540-1600,        acosta jose de 15401600
# 12      Kircher, Athanasius, 1602-1680.    kircher athanasius 16021680
# 13          Mersenne, Marin, 1588-1648,        mersenne marin 15881648
# 14                              Virgil.                         virgil
# 15         Kepler, Johannes, 1571-1630.       kepler johannes 15711630
# 18          Alvares, Manuel, 1526-1583.        alvares manuel 15261583
# 26                              Virgil.                         virgil
# 27                      Boethius, -524.                   boethius 524
# 30  Thomas, Aquinas, Saint, 1225?-1274.  thomas aquinas saint 12251274
#
#               deterministic_author                    fuzzy_author  \
# 6   kircher, athanasius, 1602-1680  kircher, athanasius, 1602-1680
# 8      acosta, josé de, 1540-1600     acosta, josé de, 1540-1600
# 12  kircher, athanasius, 1602-1680  kircher, athanasius, 1602-1680
# 13      mersenne, marin, 1588-1648      mersenne, marin, 1588-1648
# 14                          virgil                          virgil
# 15                kepler, johannes                kepler, johannes
# 18      alvares, manuel, 1526-1583      alvares, manuel, 1526-1583
# 26                          virgil                          virgil
# 27                  boethius, -524                  boethius, -524
# 30          thomas, aquinas, saint          thomas, aquinas, saint
#
#     fuzzy_author_score               distilbert_author  \
# 6                  1.0  kircher, athanasius, 1602-1680
# 8                  1.0     acosta, josé de, 1540-1600
# 12                 1.0  kircher, athanasius, 1602-1680
# 13                 1.0      mersenne, marin, 1588-1648
# 14                 1.0                          virgil
# 15                 1.0                kepler, johannes
# 18                 1.0      alvares, manuel, 1526-1583
# 26                 1.0                          virgil
# 27                 1.0                  boethius, -524
# 30                 1.0          thomas, aquinas, saint
#
#     distilbert_author_score
# 6                  0.999991
# 8                  0.999997
# 12                 0.999991
# 13                 0.999985
# 14                 0.999874
# 15                 0.999983
# 18                 0.999919
# 26                 0.999874
# 27                 0.999951
# 30                 0.999990

# %% [markdown]
# The intersection of deterministic matches and model inference matches with a confidence rating higher than 0.9901 yielded 4,283 rows.
#
# **Conclusion**: The model performs *at least* as well as the deterministic model. But that is a pretty low bar!

# %% [markdown]
# ## Comparison: Model vs. Probabilistic Matching

# %% [markdown]
# The fuzzy matching algorithm's usefulness drops significantly for rows with a confidence score under 1.0, which is why I set that as the benchmark in the `fuzzy_author_match()` function above.

# %%
# Sort the dataframe by the fuzzy_author_score column in descending order
sorted_fuzzy = output_df.sort_values(by='fuzzy_author_score', ascending=False)
# Filter the results to show the intersection of fuzzy matches that are 1.0 and model matches that are not null 
high_confidence_probabilistic = sorted_fuzzy[
    (sorted_fuzzy['fuzzy_author_score'] == 1.0) &
    (sorted_fuzzy['distilbert_author_score'].notnull())
]
print(f"Number of rows with high confidence matches: {len(high_confidence_probabilistic)}")
print("Top ten high confidence probabilistic matches:")
display(high_confidence_probabilistic.head(10))
print("Bottom ten high confidence probabilistic matches:")
display(high_confidence_probabilistic.tail(10))
# Out:
# Number of rows with high confidence matches: 4522
# Top ten high confidence probabilistic matches:
#                                     author              normalized_author  \
# 4401                               Horace.                         horace
# 4070               Cicero, Marcus Tullius.          cicero marcus tullius
# 9752            Gretser, Jakob, 1562-1625.         gretser jakob 15621625
# 4067                   Tacitus, Cornelius.              tacitus cornelius
# 9751            Gretser, Jakob, 1562-1625.         gretser jakob 15621625
# 11608  Sayer, Gregory, (O.S.B.), 1560-1602     sayer gregory osb 15601602
# 4062                         Lucan, 39-65.                     lucan 3965
# 4058    Polignac, Melchior de, 1661-1742?.  polignac melchior de 16611742
# 4054         Schottus, Andreas, 1552-1629.      schottus andreas 15521629
# 4053                               Virgil.                         virgil
#
#                     deterministic_author                       fuzzy_author  \
# 4401                              horace                             horace
# 4070              cicero, marcus tullius             cicero, marcus tullius
# 9752           gretser, jakob, 1562-1625          gretser, jakob, 1562-1625
# 4067                  tacitus, cornelius                 tacitus, cornelius
# 9751           gretser, jakob, 1562-1625          gretser, jakob, 1562-1625
# 11608          sayer, gregory, 1560-1602          sayer, gregory, 1560-1602
# 4062                               lucan                              lucan
# 4058   polignac, melchior de, 1661-1742?  polignac, melchior de, 1661-1742?
# 4054        schottus, andreas, 1552-1629       schottus, andreas, 1552-1629
# 4053                              virgil                             virgil
#
#        fuzzy_author_score                  distilbert_author  \
# 4401                  1.0                             horace
# 4070                  1.0             cicero, marcus tullius
# 9752                  1.0          gretser, jakob, 1562-1625
# 4067                  1.0                 tacitus, cornelius
# 9751                  1.0          gretser, jakob, 1562-1625
# 11608                 1.0          sayer, gregory, 1560-1602
# 4062                  1.0                              lucan
# 4058                  1.0  polignac, melchior de, 1661-1742?
# 4054                  1.0       schottus, andreas, 1552-1629
# 4053                  1.0                             virgil
#
#        distilbert_author_score
# 4401                  0.999989
# 4070                  0.999886
# 9752                  0.999982
# 4067                  0.999989
# 9751                  0.999982
# 11608                 0.999995
# 4062                  0.999983
# 4058                  0.999990
# 4054                  0.999968
# 4053                  0.999874
# Bottom ten high confidence probabilistic matches:
#                                       author  \
# 1938               Keil, Heinrich, 1822-1894
# 2600        Ovid, 43 B.C.-17 A.D. or 18 A.D.
# 8336     Burchardus, Episcopus Wormaciensis.
# 2306                                   Livy.
# 1936   Weichert, Jonathan August, 1788-1844.
# 12501  Séneca, Lucio Anneo, ca. 4 a.C-65 d.C
# 2596                          Boethius, -524
# 2307        Ovid, 43 B.C.-17 A.D. or 18 A.D.
# 2308                 Lucretius Carus, Titus.
# 2303        Ovid, 43 B.C.-17 A.D. or 18 A.D.
#
#                        normalized_author  \
# 1938              keil heinrich 18221894
# 2600            ovid 43 bc17 ad or 18 ad
# 8336   burchardus episcopus wormaciensis
# 2306                                livy
# 1936   weichert jonathan august 17881844
# 12501    seneca lucio anneo ca 4 ac65 dc
# 2596                        boethius 524
# 2307            ovid 43 bc17 ad or 18 ad
# 2308               lucretius carus titus
# 2303            ovid 43 bc17 ad or 18 ad
#
#                                     deterministic_author  \
# 1938                           keil, heinrich, 1822-1894
# 2600                    ovid, 43 b.c.-17 a.d. or 18 a.d.
# 8336                                                None
# 2306                                                livy
# 1936                         weichert, august, 1788-1844
# 12501  seneca, lucius annaeus, approximately 4 b.c.-6...
# 2596                                      boethius, -524
# 2307                    ovid, 43 b.c.-17 a.d. or 18 a.d.
# 2308                              lucretius carus, titus
# 2303                    ovid, 43 b.c.-17 a.d. or 18 a.d.
#
#                                             fuzzy_author  fuzzy_author_score  \
# 1938                           keil, heinrich, 1822-1894                 1.0
# 2600                    ovid, 43 b.c.-17 a.d. or 18 a.d.                 1.0
# 8336                           burchard, bishop of worms                 1.0
# 2306                                                livy                 1.0
# 1936                         weichert, august, 1788-1844                 1.0
# 12501  seneca, lucius annaeus, approximately 4 b.c.-6...                 1.0
# 2596                                      boethius, -524                 1.0
# 2307                    ovid, 43 b.c.-17 a.d. or 18 a.d.                 1.0
# 2308                              lucretius carus, titus                 1.0
# 2303                    ovid, 43 b.c.-17 a.d. or 18 a.d.                 1.0
#
#                                        distilbert_author  \
# 1938                           keil, heinrich, 1822-1894
# 2600                    ovid, 43 b.c.-17 a.d. or 18 a.d.
# 8336                           burchard, bishop of worms
# 2306                                                livy
# 1936                         weichert, august, 1788-1844
# 12501  seneca, lucius annaeus, approximately 4 b.c.-6...
# 2596                                      boethius, -524
# 2307                    ovid, 43 b.c.-17 a.d. or 18 a.d.
# 2308                              lucretius carus, titus
# 2303                    ovid, 43 b.c.-17 a.d. or 18 a.d.
#
#        distilbert_author_score
# 1938                  0.999944
# 2600                  0.999990
# 8336                  0.999926
# 2306                  0.999558
# 1936                  0.999972
# 12501                 0.999839
# 2596                  0.999960
# 2307                  0.999990
# 2308                  0.999990
# 2303                  0.999990

# %%
high_confidence_probabilistic.describe()
# Out:
#        fuzzy_author_score  distilbert_author_score
# count              4522.0              4522.000000
# mean                  1.0                 0.996303
# std                   0.0                 0.045436
# min                   1.0                 0.088868
# 25%                   1.0                 0.999886
# 50%                   1.0                 0.999975
# 75%                   1.0                 0.999989
# max                   1.0                 0.999999

# %%
# Count number of rows with a distilbert_author_score of 0.90 or lower
low_confidence_inferences = high_confidence_probabilistic[high_confidence_probabilistic['distilbert_author_score'] <= 0.90]
print(f"Number of rows with a distilbert_author_score of 0.90 or lower: {len(low_confidence_inferences)}")
# Out:
# Number of rows with a distilbert_author_score of 0.90 or lower: 33

# %% [markdown]
# **Conclusion**: The model appears to be keeping up with the probabilistic matching algorithm's high confidence (==1.0) matches. It fails on some low percentage author names, but otherwise it is performing well.

# %% [markdown]
# ## Examining the Model's Confidence
#
# Let's see what the model was confident about when the other methods lacked confidence.

# %%
# Filter the results to show only rows where the distilbert_author_score is high, the fuzzy_author_score is less than 1.0, and the deterministic_author is "None"
high_confidence_inference = output_df[
    (output_df['distilbert_author_score'] > 0.99957) &
    (output_df['fuzzy_author_score'] < 1.0) &
    ((output_df['deterministic_author'].isnull()) | (output_df['deterministic_author'] == "None"))
]
print(f"Number of rows with high confidence inference matches: {len(high_confidence_inference)}")
print("Top ten high confidence inference matches:")
display(high_confidence_inference.head(10))
print("Bottom ten high confidence inference matches:")
display(high_confidence_inference.tail(10))
# Write the high confidence inference matches to a CSV file
high_confidence_inference.to_csv('./high_confidence_inference.csv',index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
# Out:
# Number of rows with high confidence inference matches: 1755
# Top ten high confidence inference matches:
#                                                 author  \
# 1                        Meyer, Ernst H. F. 1791-1858.
# 7    Hincmar, Archbishop of Reims, approximately 80...
# 28   Prosper, of Aquitaine, Saint, approximately 39...
# 29                                   Vitruvius Pollio.
# 33                  Juvencus, Caius Vettius Aquilinus.
# 42        Valerius Flaccus, Gaius, active 1st century.
# 55               Nonius Marcellus, active 4th century.
# 78                                 Propertius, Sextus.
# 86                        Horatius, Romanus, fl. 1450.
# 112                           Catullus, Gaius Valerius
#
#                                      normalized_author deterministic_author  \
# 1                             meyer ernst h f 17911858                 None
# 7     hincmar archbishop of reims approximately 806882                 None
# 28   prosper of aquitaine saint approximately 390ap...                 None
# 29                                    vitruvius pollio                 None
# 33                    juvencus caius vettius aquilinus                 None
# 42           valerius flaccus gaius active 1st century                 None
# 55                 nonius marcellus active 4th century                 None
# 78                                   propertius sextus                 None
# 86                            horatius romanus fl 1450                 None
# 112                            catullus gaius valerius                 None
#
#                           fuzzy_author  fuzzy_author_score  \
# 1                                 None            0.000000
# 7                                 None            0.000000
# 28                                None            0.000000
# 29                    vitruvius pollio            0.941176
# 33   juvencus, caius vettius aquilinus            0.968750
# 42                                None            0.000000
# 55                                None            0.000000
# 78                                None            0.000000
# 86                                None            0.000000
# 112           catullus, gaius valerius            0.956522
#
#                      distilbert_author  distilbert_author_score
# 1            meyer, wilhelm, 1845-1917                 0.999956
# 7         hincmar, archbishop of reims                 0.999999
# 28        prosper, of aquitaine, saint                 0.999984
# 29                    vitruvius pollio                 0.999980
# 33   juvencus, caius vettius aquilinus                 0.999997
# 42             valerius flaccus, gaius                 0.999995
# 55                    nonius marcellus                 0.999963
# 78                  propertius, sextus                 0.999681
# 86                    horatius romanus                 0.999950
# 112           catullus, gaius valerius                 0.999993
# Bottom ten high confidence inference matches:
#                                                   author  \
# 13357                        Ovid, 43 B.C.-17 or 18 A.D.
# 13359                        Ovid, 43 B.C.-17 or 18 A.D.
# 13361                        Ovid, 43 B.C.-17 or 18 A.D.
# 13369                                        Quintilian.
# 13388                           Wycliffe, John, d. 1384.
# 13389                       Buchanan, David, 1595?-1652?
# 13400       Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# 13410  Palingenio Stellato, Marcello, ca. 1500-ca. 1543.
# 13422                        Ovid, 43 B.C.-17 or 18 A.D.
# 13423                        Ovid, 43 B.C.-17 or 18 A.D.
#
#                                  normalized_author deterministic_author  \
# 13357                        ovid 43 bc17 or 18 ad                 None
# 13359                        ovid 43 bc17 or 18 ad                 None
# 13361                        ovid 43 bc17 or 18 ad                 None
# 13369                                   quintilian                 None
# 13388                         wycliffe john d 1384                 None
# 13389                      buchanan david 15951652                 None
# 13400         velleius paterculus ca 19 bcca 30 ad                 None
# 13410  palingenio stellato marcello ca 1500ca 1543                 None
# 13422                        ovid 43 bc17 or 18 ad                 None
# 13423                        ovid 43 bc17 or 18 ad                 None
#
#                                             fuzzy_author  fuzzy_author_score  \
# 13357                   ovid, 43 b.c.-17 a.d. or 18 a.d.            0.933333
# 13359                   ovid, 43 b.c.-17 a.d. or 18 a.d.            0.933333
# 13361                   ovid, 43 b.c.-17 a.d. or 18 a.d.            0.933333
# 13369                                         quintilian            0.952381
# 13388                              wycliffe, john, -1384            0.947368
# 13389                                               None            0.000000
# 13400                                               None            0.000000
# 13410  palingenio stellato, marcello, approximately 1...            0.931818
# 13422                   ovid, 43 b.c.-17 a.d. or 18 a.d.            0.933333
# 13423                   ovid, 43 b.c.-17 a.d. or 18 a.d.            0.933333
#
#                                        distilbert_author  \
# 13357                   ovid, 43 b.c.-17 a.d. or 18 a.d.
# 13359                   ovid, 43 b.c.-17 a.d. or 18 a.d.
# 13361                   ovid, 43 b.c.-17 a.d. or 18 a.d.
# 13369                                         quintilian
# 13388                              wycliffe, john, -1384
# 13389                                   buchanan, george
# 13400                                velleius paterculus
# 13410  palingenio stellato, marcello, approximately 1...
# 13422                   ovid, 43 b.c.-17 a.d. or 18 a.d.
# 13423                   ovid, 43 b.c.-17 a.d. or 18 a.d.
#
#        distilbert_author_score
# 13357                 0.999990
# 13359                 0.999990
# 13361                 0.999990
# 13369                 0.999983
# 13388                 0.999988
# 13389                 0.999811
# 13400                 0.999971
# 13410                 0.999989
# 13422                 0.999990
# 13423                 0.999990

# %% [markdown]
# It appears that when the model's confidence is above 0.999957, it accurately matches authors that neither the deterministic nor the probabilistic algorithms can match. I arrived at that number by adjusting it up or down until I found the exact number that had only positive results for the model.

# %% [markdown]
# ## Where the Model Fails

# %%
# Filter the results to show the intersection of deterministic matches that aren't "None", the fuzzy_author_score is equal to 1.0, and the model matches are less than 0.9
high_confidence_deterministic_fuzzy = output_df[
    (output_df['deterministic_author'].notnull() & (output_df['deterministic_author'] != "None")) &
    (output_df['fuzzy_author_score'] == 1.0) &
    (output_df['distilbert_author_score'] < 0.9)
]
print(f"Number of rows with high confidence deterministic and fuzzy matches: {len(high_confidence_deterministic_fuzzy)}")
print("Top ten high confidence deterministic and fuzzy matches:")
display(high_confidence_deterministic_fuzzy.head(10))
print("Bottom ten high confidence deterministic and fuzzy matches:")
display(high_confidence_deterministic_fuzzy.tail(10))
# Out:
# Number of rows with high confidence deterministic and fuzzy matches: 31
# Top ten high confidence deterministic and fuzzy matches:
#                             author          normalized_author  \
# 17   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 19   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 24   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 25  Suárez, Francisco, 1548-1617.  suarez francisco 15481617
# 38   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 39  Suárez, Francisco, 1548-1617.  suarez francisco 15481617
# 40   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 48   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 51   Suarez, Francisco, 1548-1617.  suarez francisco 15481617
# 63  Suárez, Francisco, 1548-1617.  suarez francisco 15481617
#
#              deterministic_author                   fuzzy_author  \
# 17  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 19  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 24  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 25  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 38  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 39  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 40  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 48  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 51  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
# 63  suárez, francisco, 1548-1617  suárez, francisco, 1548-1617
#
#     fuzzy_author_score                 distilbert_author  \
# 17                 1.0  gonzález téllez, manuel, -1649
# 19                 1.0  gonzález téllez, manuel, -1649
# 24                 1.0  gonzález téllez, manuel, -1649
# 25                 1.0  gonzález téllez, manuel, -1649
# 38                 1.0  gonzález téllez, manuel, -1649
# 39                 1.0  gonzález téllez, manuel, -1649
# 40                 1.0  gonzález téllez, manuel, -1649
# 48                 1.0  gonzález téllez, manuel, -1649
# 51                 1.0  gonzález téllez, manuel, -1649
# 63                 1.0  gonzález téllez, manuel, -1649
#
#     distilbert_author_score
# 17                 0.410325
# 19                 0.410325
# 24                 0.410325
# 25                 0.597960
# 38                 0.410325
# 39                 0.597960
# 40                 0.410325
# 48                 0.410325
# 51                 0.410325
# 63                 0.597960
# Bottom ten high confidence deterministic and fuzzy matches:
#                                author          normalized_author  \
# 4497                         Terence.                    terence
# 6200                         Terence.                    terence
# 6704   Suárez, Francisco, 1548-1617.  suarez francisco 15481617
# 6705   Suárez, Francisco, 1548-1617.  suarez francisco 15481617
# 6706      Müller, Lucian, 1836-1898.     muller lucian 18361898
# 6967    Suárez, Francisco, 1548-1617  suarez francisco 15481617
# 6988   Bèze, Théodore de, 1519-1605  beze theodore de 15191605
# 11312               Alanus de Insulis          alanus de insulis
# 11573      De Vío, Tommaso, 1469-1534    de vio tommaso 14691534
# 13380  Suárez, Francisco, 1548-1617.  suarez francisco 15481617
#
#                      deterministic_author                        fuzzy_author  \
# 4497                              terence                             terence
# 6200                              terence                             terence
# 6704        suárez, francisco, 1548-1617       suárez, francisco, 1548-1617
# 6705        suárez, francisco, 1548-1617       suárez, francisco, 1548-1617
# 6706           müller, lucian, 1836-1898          müller, lucian, 1836-1898
# 6967        suárez, francisco, 1548-1617       suárez, francisco, 1548-1617
# 6988       bèze, théodore de, 1519-1605      bèze, théodore de, 1519-1605
# 11312                  alanus, de insulis                  alanus, de insulis
# 11573  cajetan, tommaso de vio, 1469-1534  cajetan, tommaso de vio, 1469-1534
# 13380       suárez, francisco, 1548-1617       suárez, francisco, 1548-1617
#
#        fuzzy_author_score                   distilbert_author  \
# 4497                  1.0          linacre, thomas, 1460-1524
# 6200                  1.0          linacre, thomas, 1460-1524
# 6704                  1.0    gonzález téllez, manuel, -1649
# 6705                  1.0    gonzález téllez, manuel, -1649
# 6706                  1.0          müller, lucian, 1836-1898
# 6967                  1.0    gonzález téllez, manuel, -1649
# 6988                  1.0              bero magni, de ludosia
# 11312                 1.0                  alanus, de insulis
# 11573                 1.0  cajetan, tommaso de vio, 1469-1534
# 13380                 1.0    gonzález téllez, manuel, -1649
#
#        distilbert_author_score
# 4497                  0.128482
# 6200                  0.128482
# 6704                  0.597960
# 6705                  0.597960
# 6706                  0.863094
# 6967                  0.522586
# 6988                  0.204709
# 11312                 0.845193
# 11573                 0.731794
# 13380                 0.597960

# %%
# Unique values in the "author" column of the high_confidence_deterministic_fuzzy dataframe
unique_authors_deterministic_fuzzy = high_confidence_deterministic_fuzzy['normalized_author'].nunique()
print(f"Number of unique authors in the high confidence deterministic and fuzzy matches: {unique_authors_deterministic_fuzzy}")
authors_not_matched_by_model = set(high_confidence_deterministic_fuzzy['normalized_author'].to_list())
for author in sorted(authors_not_matched_by_model):
    print(author)
# Out:
# Number of unique authors in the high confidence deterministic and fuzzy matches: 7
# alanus de insulis
# beze theodore de 15191605
# de vio tommaso 14691534
# muller lucian 18361898
# schoen henricus
# suarez francisco 15481617
# terence

# %% [markdown]
# ## What can be learned about the model's performance?

# %%
# How many rows have a 1.0 distilbert_author_score?
perfect_inferences = output_df[output_df['distilbert_author_score'] >= 0.999957]
print(f"Number of rows with a near perfect distilbert_author_score: {len(perfect_inferences)}")
# Out:
# Number of rows with a near perfect distilbert_author_score: 3876

# %%
# How many unique authors are in the perfect_inferences dataframe?
unique_perfect_inferences = perfect_inferences['normalized_author'].nunique()
print(f"Number of unique authors in the perfect_inferences dataframe: {unique_perfect_inferences}")
# Out:
# Number of unique authors in the perfect_inferences dataframe: 623

# %% [markdown]
# ## Conclusions
#
# Overall, the model performs better than the deterministic and probabilistic algorithms, but there is room for improvement. Where the deterministic and probabilistic algorithms have high confidence but the model's confidence is less than 0.9, there were 31 records.
#
# There were seven actually unique authors among those 31 records:
#
# - Alanus de Insulis
# - Bèze, Théodore de, 1519-1605
# - De Vío, Tommaso, 1469-1534
# - Müller, Lucian, 1836-1898.
# - Schoen, Henricus.
# - Suarez, Francisco, 1548-1617,
# - Terence
#
# If I augment the rows for these authors in the training data, it is likely that the model will match these, too. It really should have matched "Terence". That's … odd.
